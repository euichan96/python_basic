# %%
import numpy as np 
import pandas as pd 
import datetime

import numpy
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.datasets import reuters
from keras.models import Sequential
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense,LSTM,Embedding
from keras.layers import Dense, LSTM, Embedding
from keras.preprocessing import sequence
from keras.utils import np_utils

seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)
from keras.callbacks import ModelCheckpoint, EarlyStopping
import os

# %%
#print(items_frm.head(3))             # 아이템, 카테고리 라벨링
#print('---------')
#print(sample_submission_frm.head(3)) # 제출양식
#print(item_categories_frm.head(3))   # 카테고리 이름, 라벨링
#print(sales_train_frm.head(3))       #
#print(shops_frm.head(3))             # 상점 라벨링
#test_frm             #

# %%
#제출 형식 예제
sample_submission = pd.read_csv('data/sample_submission.csv')
sample_submission
#달 단위 결과
# Out:
#             ID  item_cnt_month
# 0            0             0.5
# 1            1             0.5
# 2            2             0.5
# 3            3             0.5
# 4            4             0.5
# ...        ...             ...
# 214195  214195             0.5
# 214196  214196             0.5
# 214197  214197             0.5
# 214198  214198             0.5
# 214199  214199             0.5
#
# [214200 rows x 2 columns]

# %%
shops = pd.read_csv('data/shops.csv')
shops
# Out:
#                                           shop_name  shop_id
# 0                     !Якутск Орджоникидзе, 56 фран        0
# 1                     !Якутск ТЦ "Центральный" фран        1
# 2                                  Адыгея ТЦ "Мега"        2
# 3                    Балашиха ТРК "Октябрь-Киномир"        3
# 4                          Волжский ТЦ "Волга Молл"        4
# 5                            Вологда ТРЦ "Мармелад"        5
# 6                        Воронеж (Плехановская, 13)        6
# 7                            Воронеж ТРЦ "Максимир"        7
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8
# 9                                 Выездная Торговля        9
# 10                       Жуковский ул. Чкалова 39м?       10
# 11                       Жуковский ул. Чкалова 39м²       11
# 12                              Интернет-магазин ЧС       12
# 13                              Казань ТЦ "Бехетле"       13
# 14                          Казань ТЦ "ПаркХаус" II       14
# 15                             Калуга ТРЦ "XXI век"       15
# 16                                 Коломна ТЦ "Рио"       16
# 17                    Красноярск ТЦ "Взлетка Плаза"       17
# 18                             Красноярск ТЦ "Июнь"       18
# 19                            Курск ТЦ "Пушкинский"       19
# 20                              Москва "Распродажа"       20
# 21                           Москва МТРЦ "Афи Молл"       21
# 22                               Москва Магазин С21       22
# 23                 Москва ТК "Буденовский" (пав.А2)       23
# 24                 Москва ТК "Буденовский" (пав.К7)       24
# 25                              Москва ТРК "Атриум"       25
# 26                      Москва ТЦ "Ареал" (Беляево)       26
# 27                   Москва ТЦ "МЕГА Белая Дача II"       27
# 28                  Москва ТЦ "МЕГА Теплый Стан" II       28
# 29               Москва ТЦ "Новый век" (Новокосино)       29
# 30                           Москва ТЦ "Перловский"       30
# 31                          Москва ТЦ "Семеновский"       31
# 32                       Москва ТЦ "Серебряный Дом"       32
# 33                                Мытищи ТРК "XL-3"       33
# 34                             Н.Новгород ТРЦ "РИО"       34
# 35                      Н.Новгород ТРЦ "Фантастика"       35
# 36            Новосибирск ТРЦ "Галерея Новосибирск"       36
# 37                            Новосибирск ТЦ "Мега"       37
# 38                                   Омск ТЦ "Мега"       38
# 39            РостовНаДону ТРК "Мегацентр Горизонт"       39
# 40  РостовНаДону ТРК "Мегацентр Горизонт" Островной       40
# 41                           РостовНаДону ТЦ "Мега"       41
# 42                           СПб ТК "Невский Центр"       42
# 43                                  СПб ТК "Сенная"       43
# 44                              Самара ТЦ "Мелодия"       44
# 45                             Самара ТЦ "ПаркХаус"       45
# 46                            Сергиев Посад ТЦ "7Я"       46
# 47                           Сургут ТРЦ "Сити Молл"       47
# 48                     Томск ТРЦ "Изумрудный Город"       48
# 49                            Тюмень ТРЦ "Кристалл"       49
# 50                               Тюмень ТЦ "Гудвин"       50
# 51                        Тюмень ТЦ "Зеленый Берег"       51
# 52                             Уфа ТК "Центральный"       52
# 53                                 Уфа ТЦ "Семья" 2       53
# 54                                  Химки ТЦ "Мега"       54
# 55                         Цифровой склад 1С-Онлайн       55
# 56                             Чехов ТРЦ "Карнавал"       56
# 57                          Якутск Орджоникидзе, 56       57
# 58                          Якутск ТЦ "Центральный"       58
# 59                           Ярославль ТЦ "Альтаир"       59

# %%
items = pd.read_csv('data/items.csv')
items
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# ...                                                  ...      ...
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id
# 0                    40
# 1                    76
# 2                    40
# 3                    40
# 4                    40
# ...                 ...
# 22165                31
# 22166                54
# 22167                49
# 22168                62
# 22169                69
#
# [22170 rows x 3 columns]

# %%
sales_train = pd.read_csv('data/sales_train.csv')
sales_train
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %%
print(type(sales_train.date[0]) , sales_train.date[0])
sales_train.info()
# Out:
# <class 'str'> 02.01.2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
#for i in range(len(sales_train)):
#    sales_train.date[i] = datetime.datetime.strptime(sales_train.date[i],'%d.%m.%Y')

# %%
sales_train.date=sales_train.date.apply(
    lambda x:datetime.datetime.strptime(x, '%d.%m.%Y'))

# %%
print(type(sales_train.date[0]) , sales_train.date[0])
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'> 2013-01-02 00:00:00

# %%
import matplotlib.pyplot as plt

sales_train.hist(bins = 100, figsize = (20,15))
plt.show()

# %%
pd.plotting.scatter_matrix(sales_train, figsize = (10,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/214399787.py in <module>
#       1 pd.plotting.scatter_matrix(sales_train, figsize = (10,10))
# ----> 2 plt.show()
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2317                 # force the figure dpi to 72), so we need to set it again here.
#    2318                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319                     result = print_method(
#    2320                         filename,
#    2321                         facecolor=facecolor,
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2808
#    2809             self.patch.draw(renderer)
# -> 2810             mimage._draw_list_compositing_images(
#    2811                 renderer, self, artists, self.suppressComposite)
#    2812
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     989     def draw(self, renderer):
#     990         self.set_sizes(self._sizes, self.figure.dpi)
# --> 991         super().draw(renderer)
#     992
#     993
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     424                 mpath.Path(offsets), transOffset, tuple(facecolors[0]))
#     425         else:
# --> 426             renderer.draw_path_collection(
#     427                 gc, transform.frozen(), paths,
#     428                 self.get_transforms(), offsets, transOffset,
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\path.py in vertices(self)
#     198         )
#     199
# --> 200     @property
#     201     def vertices(self):
#     202         """
#
# KeyboardInterrupt:

# %%
sales_train['price_hap'] = sales_train['item_price'] * sales_train['item_cnt_day']

# %%
daily_sales = sales_train.groupby('date', as_index=False)['price_hap'].sum()
store_daily_sales = sales_train.groupby(['shop_id', 'date'], as_index=False)['price_hap'].sum()
item_daily_sales = sales_train.groupby(['item_id', 'date'], as_index=False)['price_hap'].sum()

# %%
# 일별 총 판매량
plt.figure(figsize=(20,8))
plt.plot(daily_sales['date'],daily_sales['price_hap'])
plt.title('Daily sales')
plt.xlabel('Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
# 일별, Store별 총 판매량
plt.figure(figsize=(20,8))

for i in range(0,60) :
    temp = store_daily_sales[store_daily_sales.shop_id==i]
    plt.plot(temp['date'],temp['price_hap'], label = 'Store %d' % i)

plt.legend()
plt.title('Store Daily Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
# Out:
# array([    0,     1,     2, ..., 22167, 22168, 22169], dtype=int64)

# %%
# 일별, Item별 총 판매량

plt.figure(figsize=(20,8))

for i in item_daily_sales.item_id.unique():
    temp = item_daily_sales[item_daily_sales.item_id==i]
    plt.plot(temp['date'],temp['price_hap'], label = 'Item %d' %i)

# plt.legend()
plt.title('Item Daily Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/2365191225.py in <module>
#       5 for i in item_daily_sales.item_id.unique():
#       6     temp = item_daily_sales[item_daily_sales.item_id==i]
# ----> 7     plt.plot(temp['date'],temp['price_hap'], label = 'Item %d' %i)
#       8
#       9 # plt.legend()
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     485
#     486         if len(xy) == 2:
# --> 487             x = _check_1d(xy[0])
#     488             y = _check_1d(xy[1])
#     489         else:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    1325                     message='Support for multi-dimensional indexing')
#    1326
# -> 1327                 ndim = x[:, None].ndim
#    1328                 # we have definitely hit a pandas index or series object
#    1329                 # cast to a numpy array.
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     983             return self._get_values(key)
#     984
# --> 985         return self._get_with(key)
#     986
#     987     def _get_with(self, key):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     998             )
#     999         elif isinstance(key, tuple):
# -> 1000             return self._get_values_tuple(key)
#    1001
#    1002         elif not is_list_like(key):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in _get_values_tuple(self, key)
#    1029         if com.any_none(*key):
#    1030             result = self._get_values(key)
# -> 1031             deprecate_ndim_indexing(result, stacklevel=find_stack_level())
#    1032             return result
#    1033
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\util\_exceptions.py in find_stack_level()
#      30     (tests notwithstanding).
#      31     """
# ---> 32     stack = inspect.stack()
#      33
#      34     import pandas as pd
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\inspect.py in stack(context)
#    1524 def stack(context=1):
#    1525     """Return a list of records for the stack above the caller's frame."""
# -> 1526     return getouterframes(sys._getframe(1), context)
#    1527
#    1528 def trace(context=1):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\inspect.py in getouterframes(frame, context)
#    1501     framelist = []
#    1502     while frame:
# -> 1503         frameinfo = (frame,) + getframeinfo(frame, context)
#    1504         framelist.append(FrameInfo(*frameinfo))
#    1505         frame = frame.f_back
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\inspect.py in getframeinfo(frame, context)
#    1471         raise TypeError('{!r} is not a frame or traceback object'.format(frame))
#    1472
# -> 1473     filename = getsourcefile(frame) or getfile(frame)
#    1474     if context > 0:
#    1475         start = lineno - 1 - context//2
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\inspect.py in getsourcefile(object)
#     703                  importlib.machinery.EXTENSION_SUFFIXES):
#     704         return None
# --> 705     if os.path.exists(filename):
#     706         return filename
#     707     # only return a non-existent filename if the module has a PEP 302 loader
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# KeyboardInterrupt:

# %%
def series_to_supervised(data, window=1, lag=1, dropnan=True):
    cols, names = list(), list()
    # Input sequence (t-n, ... t-1)
    for i in range(window, 0, -1):
        cols.append(data.shift(i))
        names += [('%s(t-%d)' % (col, i)) for col in data.columns]
    # Current timestep (t=0)
    cols.append(data)
    names += [('%s(t)' % (col)) for col in data.columns]
    # Target timestep (t=lag)
    cols.append(data.shift(-lag))
    names += [('%s(t+%d)' % (col, lag)) for col in data.columns]
    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # Drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
    
train_gp = sales_train.sort_values('date').groupby(["date_block_num","shop_id"], as_index=False)
train_gp = train_gp.agg({'price_hap':['mean']})
train_gp.columns = ['date_block_num', 'store_id', 'price_hap']

window = 33
lag_size =1
lag=lag_size
series = series_to_supervised(train_gp.drop('price_hap', axis=1), window=window, lag=lag)


last_store = 'store_id(t-%d)' % window
series = series[(series['store_id(t)'] == series[last_store])]

columns_to_drop = [('%s(t+%d)' % (col, lag)) for col in ['store_id']]
for i in range(window, 0, -1):
    columns_to_drop += [('%s(t-%d)' % (col, i)) for col in ['store_id']]
series.drop(columns_to_drop, axis=1, inplace=True)
series.drop([ 'store_id(t)'], axis=1, inplace=True)

# %%
train_data = train_gp.copy()
train_data.drop(['price_hap'],axis =1,inplace=True)
train_data
# Out:
#       date_block_num  store_id
# 0                  0         0
# 1                  0         1
# 2                  0         2
# 3                  0         3
# 4                  0         4
# ...              ...       ...
# 1581              33        55
# 1582              33        56
# 1583              33        57
# 1584              33        58
# 1585              33        59
#
# [1586 rows x 2 columns]

# %%
train_data
# Out:
#       date_block_num  store_id
# 0                  0         0
# 1                  0         1
# 2                  0         2
# 3                  0         3
# 4                  0         4
# ...              ...       ...
# 1581              33        55
# 1582              33        56
# 1583              33        57
# 1584              33        58
# 1585              33        59
#
# [1586 rows x 2 columns]

# %%
train_gp.price_hap
# Out:
# 0        618.905070
# 1        566.933927
# 2       1013.132400
# 3        748.444606
# 4        756.951426
#            ...
# 1581    1103.655750
# 1582    1133.959657
# 1583    1153.838663
# 1584    1327.024096
# 1585    1334.316872
# Name: price_hap, Length: 1586, dtype: float64

# %%
from sklearn.model_selection import train_test_split



X_train, X_valid, Y_train, Y_valid = train_test_split(train_data, train_gp.price_hap, test_size=0.3, random_state=0)

# %%
print(X_train, X_valid, Y_train, Y_valid)
# Out:
#       date_block_num  store_id
# 247                5        26
# 1261              26        39
# 456               10         2
# 813               17        39
# 757               16        28
# ...              ...       ...
# 763               16        38
# 835               18         3
# 1216              25        41
# 559               12        17
# 684               14        57
#
# [1110 rows x 2 columns]       date_block_num  store_id
# 897               19        18
# 1507              32        14
# 511               11        15
# 1368              28        57
# 310                6        50
# ...              ...       ...
# 1308              27        39
# 1367              28        56
# 1558              33        22
# 1185              24        58
# 793               17        13
#
# [476 rows x 2 columns] 247      888.667870
# 1261    1107.468286
# 456     2739.107034
# 813     1206.623397
# 757     1059.774050
#            ...
# 763     1326.774453
# 835     1064.817927
# 1216    1027.630384
# 559     1235.439323
# 684      967.339303
# Name: price_hap, Length: 1110, dtype: float64 897     1419.171816
# 1507    1806.731560
# 511     1235.403681
# 1368    1101.462566
# 310      812.968652
#            ...
# 1308    1720.242806
# 1367    1119.660457
# 1558    1659.934025
# 1185    1164.575196
# 793      373.209150
# Name: price_hap, Length: 476, dtype: float64

# %%
print(X_train.shape, X_valid.shape ,Y_train.shape, Y_valid.shape)
X_train
# Out:
# (1110, 2) (476, 2) (1110,) (476,)
#       date_block_num  store_id
# 247                5        26
# 1261              26        39
# 456               10         2
# 813               17        39
# 757               16        28
# ...              ...       ...
# 763               16        38
# 835               18         3
# 1216              25        41
# 559               12        17
# 684               14        57
#
# [1110 rows x 2 columns]

# %%
from tensorflow.keras import optimizers

epochs = 10000
batch = 256
lr = 0.0003
adam = optimizers.Adam(lr)

model_mlp = Sequential()
model_mlp.add(Dense(100, activation='relu', input_dim=X_train.shape[1]))
model_mlp.add(Dense(1))
model_mlp.compile(loss='mse', optimizer=adam)

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='loss', patience=50)

mlp_history = model_mlp.fit(X_train.values, Y_train, validation_data=(X_valid.values, Y_valid), epochs=epochs, verbose=2, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/10000
#
# Epoch 00001: val_loss improved from inf to 1883835.62500, saving model to ./model\01-1883835.6250.hdf5
# 35/35 - 0s - loss: 1865522.7500 - val_loss: 1883835.6250 - 350ms/epoch - 10ms/step
# Epoch 2/10000
#
# Epoch 00002: val_loss improved from 1883835.62500 to 1869449.12500, saving model to ./model\02-1869449.1250.hdf5
# 35/35 - 0s - loss: 1850748.2500 - val_loss: 1869449.1250 - 46ms/epoch - 1ms/step
# Epoch 3/10000
#
# Epoch 00003: val_loss improved from 1869449.12500 to 1854991.62500, saving model to ./model\03-1854991.6250.hdf5
# 35/35 - 0s - loss: 1835953.7500 - val_loss: 1854991.6250 - 46ms/epoch - 1ms/step
# Epoch 4/10000
#
# Epoch 00004: val_loss improved from 1854991.62500 to 1839508.12500, saving model to ./model\04-1839508.1250.hdf5
# 35/35 - 0s - loss: 1820787.3750 - val_loss: 1839508.1250 - 50ms/epoch - 1ms/step
# Epoch 5/10000
#
# Epoch 00005: val_loss improved from 1839508.12500 to 1822917.50000, saving model to ./model\05-1822917.5000.hdf5
# 35/35 - 0s - loss: 1804464.6250 - val_loss: 1822917.5000 - 43ms/epoch - 1ms/step
# Epoch 6/10000
#
# Epoch 00006: val_loss improved from 1822917.50000 to 1804526.50000, saving model to ./model\06-1804526.5000.hdf5
# 35/35 - 0s - loss: 1786594.0000 - val_loss: 1804526.5000 - 45ms/epoch - 1ms/step
# Epoch 7/10000
#
# Epoch 00007: val_loss improved from 1804526.50000 to 1784465.87500, saving model to ./model\07-1784465.8750.hdf5
# 35/35 - 0s - loss: 1766792.6250 - val_loss: 1784465.8750 - 45ms/epoch - 1ms/step
# Epoch 8/10000
#
# Epoch 00008: val_loss improved from 1784465.87500 to 1762545.12500, saving model to ./model\08-1762545.1250.hdf5
# 35/35 - 0s - loss: 1745387.0000 - val_loss: 1762545.1250 - 43ms/epoch - 1ms/step
# Epoch 9/10000
#
# Epoch 00009: val_loss improved from 1762545.12500 to 1739438.12500, saving model to ./model\09-1739438.1250.hdf5
# 35/35 - 0s - loss: 1722157.7500 - val_loss: 1739438.1250 - 47ms/epoch - 1ms/step
# Epoch 10/10000
#
# Epoch 00010: val_loss improved from 1739438.12500 to 1713964.12500, saving model to ./model\10-1713964.1250.hdf5
# 35/35 - 0s - loss: 1697335.6250 - val_loss: 1713964.1250 - 44ms/epoch - 1ms/step
# Epoch 11/10000
#
# Epoch 00011: val_loss improved from 1713964.12500 to 1686673.50000, saving model to ./model\11-1686673.5000.hdf5
# 35/35 - 0s - loss: 1670319.1250 - val_loss: 1686673.5000 - 59ms/epoch - 2ms/step
# Epoch 12/10000
#
# Epoch 00012: val_loss improved from 1686673.50000 to 1658219.25000, saving model to ./model\12-1658219.2500.hdf5
# 35/35 - 0s - loss: 1641489.7500 - val_loss: 1658219.2500 - 54ms/epoch - 2ms/step
# Epoch 13/10000
#
# Epoch 00013: val_loss improved from 1658219.25000 to 1628423.25000, saving model to ./model\13-1628423.2500.hdf5
# 35/35 - 0s - loss: 1611406.1250 - val_loss: 1628423.2500 - 50ms/epoch - 1ms/step
# Epoch 14/10000
#
# Epoch 00014: val_loss improved from 1628423.25000 to 1597711.62500, saving model to ./model\14-1597711.6250.hdf5
# 35/35 - 0s - loss: 1580185.1250 - val_loss: 1597711.6250 - 48ms/epoch - 1ms/step
# Epoch 15/10000
#
# Epoch 00015: val_loss improved from 1597711.62500 to 1565769.87500, saving model to ./model\15-1565769.8750.hdf5
# 35/35 - 0s - loss: 1547964.6250 - val_loss: 1565769.8750 - 48ms/epoch - 1ms/step
# Epoch 16/10000
#
# Epoch 00016: val_loss improved from 1565769.87500 to 1533168.12500, saving model to ./model\16-1533168.1250.hdf5
# 35/35 - 0s - loss: 1514741.7500 - val_loss: 1533168.1250 - 56ms/epoch - 2ms/step
# Epoch 17/10000
#
# Epoch 00017: val_loss improved from 1533168.12500 to 1500086.00000, saving model to ./model\17-1500086.0000.hdf5
# 35/35 - 0s - loss: 1480464.3750 - val_loss: 1500086.0000 - 57ms/epoch - 2ms/step
# Epoch 18/10000
#
# Epoch 00018: val_loss improved from 1500086.00000 to 1465851.87500, saving model to ./model\18-1465851.8750.hdf5
# 35/35 - 0s - loss: 1445525.1250 - val_loss: 1465851.8750 - 47ms/epoch - 1ms/step
# Epoch 19/10000
#
# Epoch 00019: val_loss improved from 1465851.87500 to 1431091.37500, saving model to ./model\19-1431091.3750.hdf5
# 35/35 - 0s - loss: 1409614.6250 - val_loss: 1431091.3750 - 48ms/epoch - 1ms/step
# Epoch 20/10000
#
# Epoch 00020: val_loss improved from 1431091.37500 to 1395714.37500, saving model to ./model\20-1395714.3750.hdf5
# 35/35 - 0s - loss: 1373159.5000 - val_loss: 1395714.3750 - 56ms/epoch - 2ms/step
# Epoch 21/10000
#
# Epoch 00021: val_loss improved from 1395714.37500 to 1359992.25000, saving model to ./model\21-1359992.2500.hdf5
# 35/35 - 0s - loss: 1336087.3750 - val_loss: 1359992.2500 - 47ms/epoch - 1ms/step
# Epoch 22/10000
#
# Epoch 00022: val_loss improved from 1359992.25000 to 1323911.75000, saving model to ./model\22-1323911.7500.hdf5
# 35/35 - 0s - loss: 1298624.3750 - val_loss: 1323911.7500 - 49ms/epoch - 1ms/step
# Epoch 23/10000
#
# Epoch 00023: val_loss improved from 1323911.75000 to 1287765.87500, saving model to ./model\23-1287765.8750.hdf5
# 35/35 - 0s - loss: 1260636.5000 - val_loss: 1287765.8750 - 48ms/epoch - 1ms/step
# Epoch 24/10000
#
# Epoch 00024: val_loss improved from 1287765.87500 to 1251113.37500, saving model to ./model\24-1251113.3750.hdf5
# 35/35 - 0s - loss: 1222593.7500 - val_loss: 1251113.3750 - 45ms/epoch - 1ms/step
# Epoch 25/10000
#
# Epoch 00025: val_loss improved from 1251113.37500 to 1215246.25000, saving model to ./model\25-1215246.2500.hdf5
# 35/35 - 0s - loss: 1184204.1250 - val_loss: 1215246.2500 - 45ms/epoch - 1ms/step
# Epoch 26/10000
#
# Epoch 00026: val_loss improved from 1215246.25000 to 1179641.37500, saving model to ./model\26-1179641.3750.hdf5
# 35/35 - 0s - loss: 1146220.3750 - val_loss: 1179641.3750 - 46ms/epoch - 1ms/step
# Epoch 27/10000
#
# Epoch 00027: val_loss improved from 1179641.37500 to 1144089.50000, saving model to ./model\27-1144089.5000.hdf5
# 35/35 - 0s - loss: 1108733.1250 - val_loss: 1144089.5000 - 57ms/epoch - 2ms/step
# Epoch 28/10000
#
# Epoch 00028: val_loss improved from 1144089.50000 to 1109697.12500, saving model to ./model\28-1109697.1250.hdf5
# 35/35 - 0s - loss: 1071418.6250 - val_loss: 1109697.1250 - 58ms/epoch - 2ms/step
# Epoch 29/10000
#
# Epoch 00029: val_loss improved from 1109697.12500 to 1075737.62500, saving model to ./model\29-1075737.6250.hdf5
# 35/35 - 0s - loss: 1034993.6875 - val_loss: 1075737.6250 - 51ms/epoch - 1ms/step
# Epoch 30/10000
#
# Epoch 00030: val_loss improved from 1075737.62500 to 1043163.56250, saving model to ./model\30-1043163.5625.hdf5
# 35/35 - 0s - loss: 999225.7500 - val_loss: 1043163.5625 - 53ms/epoch - 2ms/step
# Epoch 31/10000
#
# Epoch 00031: val_loss improved from 1043163.56250 to 1011458.00000, saving model to ./model\31-1011458.0000.hdf5
# 35/35 - 0s - loss: 964751.2500 - val_loss: 1011458.0000 - 56ms/epoch - 2ms/step
# Epoch 32/10000
#
# Epoch 00032: val_loss improved from 1011458.00000 to 981817.62500, saving model to ./model\32-981817.6250.hdf5
# 35/35 - 0s - loss: 931130.8750 - val_loss: 981817.6250 - 58ms/epoch - 2ms/step
# Epoch 33/10000
#
# Epoch 00033: val_loss improved from 981817.62500 to 953164.31250, saving model to ./model\33-953164.3125.hdf5
# 35/35 - 0s - loss: 899255.1250 - val_loss: 953164.3125 - 51ms/epoch - 1ms/step
# Epoch 34/10000
#
# Epoch 00034: val_loss improved from 953164.31250 to 926241.43750, saving model to ./model\34-926241.4375.hdf5
# 35/35 - 0s - loss: 868624.6250 - val_loss: 926241.4375 - 51ms/epoch - 1ms/step
# Epoch 35/10000
#
# Epoch 00035: val_loss improved from 926241.43750 to 900578.31250, saving model to ./model\35-900578.3125.hdf5
# 35/35 - 0s - loss: 839710.8750 - val_loss: 900578.3125 - 50ms/epoch - 1ms/step
# Epoch 36/10000
#
# Epoch 00036: val_loss improved from 900578.31250 to 876929.56250, saving model to ./model\36-876929.5625.hdf5
# 35/35 - 0s - loss: 812195.5625 - val_loss: 876929.5625 - 52ms/epoch - 1ms/step
# Epoch 37/10000
#
# Epoch 00037: val_loss improved from 876929.56250 to 854941.37500, saving model to ./model\37-854941.3750.hdf5
# 35/35 - 0s - loss: 786454.9375 - val_loss: 854941.3750 - 50ms/epoch - 1ms/step
# Epoch 38/10000
#
# Epoch 00038: val_loss improved from 854941.37500 to 834846.81250, saving model to ./model\38-834846.8125.hdf5
# 35/35 - 0s - loss: 762321.8125 - val_loss: 834846.8125 - 51ms/epoch - 1ms/step
# Epoch 39/10000
#
# Epoch 00039: val_loss improved from 834846.81250 to 816093.62500, saving model to ./model\39-816093.6250.hdf5
# 35/35 - 0s - loss: 740020.5000 - val_loss: 816093.6250 - 54ms/epoch - 2ms/step
# Epoch 40/10000
#
# Epoch 00040: val_loss improved from 816093.62500 to 799166.93750, saving model to ./model\40-799166.9375.hdf5
# 35/35 - 0s - loss: 719342.1875 - val_loss: 799166.9375 - 52ms/epoch - 1ms/step
# Epoch 41/10000
#
# Epoch 00041: val_loss improved from 799166.93750 to 783852.93750, saving model to ./model\41-783852.9375.hdf5
# 35/35 - 0s - loss: 700259.0625 - val_loss: 783852.9375 - 59ms/epoch - 2ms/step
# Epoch 42/10000
#
# Epoch 00042: val_loss improved from 783852.93750 to 769943.12500, saving model to ./model\42-769943.1250.hdf5
# 35/35 - 0s - loss: 682949.2500 - val_loss: 769943.1250 - 52ms/epoch - 1ms/step
# Epoch 43/10000
#
# Epoch 00043: val_loss improved from 769943.12500 to 757856.56250, saving model to ./model\43-757856.5625.hdf5
# 35/35 - 0s - loss: 667028.1875 - val_loss: 757856.5625 - 46ms/epoch - 1ms/step
# Epoch 44/10000
#
# Epoch 00044: val_loss improved from 757856.56250 to 747025.56250, saving model to ./model\44-747025.5625.hdf5
# 35/35 - 0s - loss: 652750.6250 - val_loss: 747025.5625 - 49ms/epoch - 1ms/step
# Epoch 45/10000
#
# Epoch 00045: val_loss improved from 747025.56250 to 737450.81250, saving model to ./model\45-737450.8125.hdf5
# 35/35 - 0s - loss: 639840.3750 - val_loss: 737450.8125 - 56ms/epoch - 2ms/step
# Epoch 46/10000
#
# Epoch 00046: val_loss improved from 737450.81250 to 728933.87500, saving model to ./model\46-728933.8750.hdf5
# 35/35 - 0s - loss: 628341.0000 - val_loss: 728933.8750 - 55ms/epoch - 2ms/step
# Epoch 47/10000
#
# Epoch 00047: val_loss improved from 728933.87500 to 721881.62500, saving model to ./model\47-721881.6250.hdf5
# 35/35 - 0s - loss: 617872.8750 - val_loss: 721881.6250 - 44ms/epoch - 1ms/step
# Epoch 48/10000
#
# Epoch 00048: val_loss improved from 721881.62500 to 715603.75000, saving model to ./model\48-715603.7500.hdf5
# 35/35 - 0s - loss: 608749.4375 - val_loss: 715603.7500 - 46ms/epoch - 1ms/step
# Epoch 49/10000
#
# Epoch 00049: val_loss improved from 715603.75000 to 710217.12500, saving model to ./model\49-710217.1250.hdf5
# 35/35 - 0s - loss: 600592.3750 - val_loss: 710217.1250 - 46ms/epoch - 1ms/step
# Epoch 50/10000
#
# Epoch 00050: val_loss improved from 710217.12500 to 705597.00000, saving model to ./model\50-705597.0000.hdf5
# 35/35 - 0s - loss: 593431.5000 - val_loss: 705597.0000 - 45ms/epoch - 1ms/step
# Epoch 51/10000
#
# Epoch 00051: val_loss improved from 705597.00000 to 701734.00000, saving model to ./model\51-701734.0000.hdf5
# 35/35 - 0s - loss: 587125.1875 - val_loss: 701734.0000 - 46ms/epoch - 1ms/step
# Epoch 52/10000
#
# Epoch 00052: val_loss improved from 701734.00000 to 698490.68750, saving model to ./model\52-698490.6875.hdf5
# 35/35 - 0s - loss: 581498.3750 - val_loss: 698490.6875 - 51ms/epoch - 1ms/step
# Epoch 53/10000
#
# Epoch 00053: val_loss improved from 698490.68750 to 695832.25000, saving model to ./model\53-695832.2500.hdf5
# 35/35 - 0s - loss: 576529.6875 - val_loss: 695832.2500 - 44ms/epoch - 1ms/step
# Epoch 54/10000
#
# Epoch 00054: val_loss improved from 695832.25000 to 693338.56250, saving model to ./model\54-693338.5625.hdf5
# 35/35 - 0s - loss: 572242.3750 - val_loss: 693338.5625 - 46ms/epoch - 1ms/step
# Epoch 55/10000
#
# Epoch 00055: val_loss improved from 693338.56250 to 691454.25000, saving model to ./model\55-691454.2500.hdf5
# 35/35 - 0s - loss: 568248.5000 - val_loss: 691454.2500 - 43ms/epoch - 1ms/step
# Epoch 56/10000
#
# Epoch 00056: val_loss improved from 691454.25000 to 689642.06250, saving model to ./model\56-689642.0625.hdf5
# 35/35 - 0s - loss: 564930.1250 - val_loss: 689642.0625 - 45ms/epoch - 1ms/step
# Epoch 57/10000
#
# Epoch 00057: val_loss improved from 689642.06250 to 688190.00000, saving model to ./model\57-688190.0000.hdf5
# 35/35 - 0s - loss: 561787.5625 - val_loss: 688190.0000 - 48ms/epoch - 1ms/step
# Epoch 58/10000
#
# Epoch 00058: val_loss improved from 688190.00000 to 686865.00000, saving model to ./model\58-686865.0000.hdf5
# 35/35 - 0s - loss: 559077.9375 - val_loss: 686865.0000 - 54ms/epoch - 2ms/step
# Epoch 59/10000
#
# Epoch 00059: val_loss improved from 686865.00000 to 685724.18750, saving model to ./model\59-685724.1875.hdf5
# 35/35 - 0s - loss: 556605.0000 - val_loss: 685724.1875 - 47ms/epoch - 1ms/step
# Epoch 60/10000
#
# Epoch 00060: val_loss improved from 685724.18750 to 684606.18750, saving model to ./model\60-684606.1875.hdf5
# 35/35 - 0s - loss: 554381.9375 - val_loss: 684606.1875 - 47ms/epoch - 1ms/step
# Epoch 61/10000
#
# Epoch 00061: val_loss improved from 684606.18750 to 683637.37500, saving model to ./model\61-683637.3750.hdf5
# 35/35 - 0s - loss: 552355.3750 - val_loss: 683637.3750 - 45ms/epoch - 1ms/step
# Epoch 62/10000
#
# Epoch 00062: val_loss improved from 683637.37500 to 682732.56250, saving model to ./model\62-682732.5625.hdf5
# 35/35 - 0s - loss: 550500.0625 - val_loss: 682732.5625 - 45ms/epoch - 1ms/step
# Epoch 63/10000
#
# Epoch 00063: val_loss improved from 682732.56250 to 681784.31250, saving model to ./model\63-681784.3125.hdf5
# 35/35 - 0s - loss: 548757.3125 - val_loss: 681784.3125 - 51ms/epoch - 1ms/step
# Epoch 64/10000
#
# Epoch 00064: val_loss improved from 681784.31250 to 680868.06250, saving model to ./model\64-680868.0625.hdf5
# 35/35 - 0s - loss: 547126.0625 - val_loss: 680868.0625 - 45ms/epoch - 1ms/step
# Epoch 65/10000
#
# Epoch 00065: val_loss improved from 680868.06250 to 679789.18750, saving model to ./model\65-679789.1875.hdf5
# 35/35 - 0s - loss: 545619.7500 - val_loss: 679789.1875 - 48ms/epoch - 1ms/step
# Epoch 66/10000
#
# Epoch 00066: val_loss improved from 679789.18750 to 678938.18750, saving model to ./model\66-678938.1875.hdf5
# 35/35 - 0s - loss: 544091.6875 - val_loss: 678938.1875 - 48ms/epoch - 1ms/step
# Epoch 67/10000
#
# Epoch 00067: val_loss improved from 678938.18750 to 678006.81250, saving model to ./model\67-678006.8125.hdf5
# 35/35 - 0s - loss: 542647.8125 - val_loss: 678006.8125 - 49ms/epoch - 1ms/step
# Epoch 68/10000
#
# Epoch 00068: val_loss improved from 678006.81250 to 676982.00000, saving model to ./model\68-676982.0000.hdf5
# 35/35 - 0s - loss: 541269.2500 - val_loss: 676982.0000 - 45ms/epoch - 1ms/step
# Epoch 69/10000
#
# Epoch 00069: val_loss improved from 676982.00000 to 675817.93750, saving model to ./model\69-675817.9375.hdf5
# 35/35 - 0s - loss: 539867.6250 - val_loss: 675817.9375 - 44ms/epoch - 1ms/step
# Epoch 70/10000
#
# Epoch 00070: val_loss improved from 675817.93750 to 674811.37500, saving model to ./model\70-674811.3750.hdf5
# 35/35 - 0s - loss: 538546.6250 - val_loss: 674811.3750 - 53ms/epoch - 2ms/step
# Epoch 71/10000
#
# Epoch 00071: val_loss improved from 674811.37500 to 673599.18750, saving model to ./model\71-673599.1875.hdf5
# 35/35 - 0s - loss: 537183.2500 - val_loss: 673599.1875 - 57ms/epoch - 2ms/step
# Epoch 72/10000
#
# Epoch 00072: val_loss improved from 673599.18750 to 672561.50000, saving model to ./model\72-672561.5000.hdf5
# 35/35 - 0s - loss: 535868.1250 - val_loss: 672561.5000 - 54ms/epoch - 2ms/step
# Epoch 73/10000
#
# Epoch 00073: val_loss improved from 672561.50000 to 671412.81250, saving model to ./model\73-671412.8125.hdf5
# 35/35 - 0s - loss: 534547.0000 - val_loss: 671412.8125 - 50ms/epoch - 1ms/step
# Epoch 74/10000
#
# Epoch 00074: val_loss improved from 671412.81250 to 670248.87500, saving model to ./model\74-670248.8750.hdf5
# 35/35 - 0s - loss: 533261.4375 - val_loss: 670248.8750 - 57ms/epoch - 2ms/step
# Epoch 75/10000
#
# Epoch 00075: val_loss improved from 670248.87500 to 668929.00000, saving model to ./model\75-668929.0000.hdf5
# 35/35 - 0s - loss: 531916.7500 - val_loss: 668929.0000 - 58ms/epoch - 2ms/step
# Epoch 76/10000
#
# Epoch 00076: val_loss improved from 668929.00000 to 667732.25000, saving model to ./model\76-667732.2500.hdf5
# 35/35 - 0s - loss: 530621.6875 - val_loss: 667732.2500 - 49ms/epoch - 1ms/step
# Epoch 77/10000
#
# Epoch 00077: val_loss improved from 667732.25000 to 666532.75000, saving model to ./model\77-666532.7500.hdf5
# 35/35 - 0s - loss: 529317.2500 - val_loss: 666532.7500 - 49ms/epoch - 1ms/step
# Epoch 78/10000
#
# Epoch 00078: val_loss improved from 666532.75000 to 665296.62500, saving model to ./model\78-665296.6250.hdf5
# 35/35 - 0s - loss: 527993.5625 - val_loss: 665296.6250 - 45ms/epoch - 1ms/step
# Epoch 79/10000
#
# Epoch 00079: val_loss improved from 665296.62500 to 664178.56250, saving model to ./model\79-664178.5625.hdf5
# 35/35 - 0s - loss: 526683.8750 - val_loss: 664178.5625 - 50ms/epoch - 1ms/step
# Epoch 80/10000
#
# Epoch 00080: val_loss improved from 664178.56250 to 663053.18750, saving model to ./model\80-663053.1875.hdf5
# 35/35 - 0s - loss: 525395.7500 - val_loss: 663053.1875 - 61ms/epoch - 2ms/step
# Epoch 81/10000
#
# Epoch 00081: val_loss improved from 663053.18750 to 661615.43750, saving model to ./model\81-661615.4375.hdf5
# 35/35 - 0s - loss: 524162.7188 - val_loss: 661615.4375 - 51ms/epoch - 1ms/step
# Epoch 82/10000
#
# Epoch 00082: val_loss improved from 661615.43750 to 660285.93750, saving model to ./model\82-660285.9375.hdf5
# 35/35 - 0s - loss: 522832.4375 - val_loss: 660285.9375 - 49ms/epoch - 1ms/step
# Epoch 83/10000
#
# Epoch 00083: val_loss improved from 660285.93750 to 659163.56250, saving model to ./model\83-659163.5625.hdf5
# 35/35 - 0s - loss: 521562.8125 - val_loss: 659163.5625 - 47ms/epoch - 1ms/step
# Epoch 84/10000
#
# Epoch 00084: val_loss improved from 659163.56250 to 657827.68750, saving model to ./model\84-657827.6875.hdf5
# 35/35 - 0s - loss: 520271.0625 - val_loss: 657827.6875 - 53ms/epoch - 2ms/step
# Epoch 85/10000
#
# Epoch 00085: val_loss improved from 657827.68750 to 656401.37500, saving model to ./model\85-656401.3750.hdf5
# 35/35 - 0s - loss: 518989.2188 - val_loss: 656401.3750 - 51ms/epoch - 1ms/step
# Epoch 86/10000
#
# Epoch 00086: val_loss improved from 656401.37500 to 655087.31250, saving model to ./model\86-655087.3125.hdf5
# 35/35 - 0s - loss: 517752.6250 - val_loss: 655087.3125 - 55ms/epoch - 2ms/step
# Epoch 87/10000
#
# Epoch 00087: val_loss improved from 655087.31250 to 653852.50000, saving model to ./model\87-653852.5000.hdf5
# 35/35 - 0s - loss: 516494.7500 - val_loss: 653852.5000 - 66ms/epoch - 2ms/step
# Epoch 88/10000
#
# Epoch 00088: val_loss improved from 653852.50000 to 652481.43750, saving model to ./model\88-652481.4375.hdf5
# 35/35 - 0s - loss: 515265.2188 - val_loss: 652481.4375 - 60ms/epoch - 2ms/step
# Epoch 89/10000
#
# Epoch 00089: val_loss improved from 652481.43750 to 651390.62500, saving model to ./model\89-651390.6250.hdf5
# 35/35 - 0s - loss: 514113.5625 - val_loss: 651390.6250 - 54ms/epoch - 2ms/step
# Epoch 90/10000
#
# Epoch 00090: val_loss improved from 651390.62500 to 650073.62500, saving model to ./model\90-650073.6250.hdf5
# 35/35 - 0s - loss: 512830.3750 - val_loss: 650073.6250 - 59ms/epoch - 2ms/step
# Epoch 91/10000
#
# Epoch 00091: val_loss improved from 650073.62500 to 648596.06250, saving model to ./model\91-648596.0625.hdf5
# 35/35 - 0s - loss: 511649.2812 - val_loss: 648596.0625 - 51ms/epoch - 1ms/step
# Epoch 92/10000
#
# Epoch 00092: val_loss improved from 648596.06250 to 647662.56250, saving model to ./model\92-647662.5625.hdf5
# 35/35 - 0s - loss: 510418.6250 - val_loss: 647662.5625 - 49ms/epoch - 1ms/step
# Epoch 93/10000
#
# Epoch 00093: val_loss improved from 647662.56250 to 646358.50000, saving model to ./model\93-646358.5000.hdf5
# 35/35 - 0s - loss: 509259.0000 - val_loss: 646358.5000 - 50ms/epoch - 1ms/step
# Epoch 94/10000
#
# Epoch 00094: val_loss improved from 646358.50000 to 645023.25000, saving model to ./model\94-645023.2500.hdf5
# 35/35 - 0s - loss: 508111.7500 - val_loss: 645023.2500 - 59ms/epoch - 2ms/step
# Epoch 95/10000
#
# Epoch 00095: val_loss improved from 645023.25000 to 644076.18750, saving model to ./model\95-644076.1875.hdf5
# 35/35 - 0s - loss: 507010.6562 - val_loss: 644076.1875 - 53ms/epoch - 2ms/step
# Epoch 96/10000
#
# Epoch 00096: val_loss improved from 644076.18750 to 642926.75000, saving model to ./model\96-642926.7500.hdf5
# 35/35 - 0s - loss: 505760.2812 - val_loss: 642926.7500 - 54ms/epoch - 2ms/step
# Epoch 97/10000
#
# Epoch 00097: val_loss improved from 642926.75000 to 641384.50000, saving model to ./model\97-641384.5000.hdf5
# 35/35 - 0s - loss: 504643.8750 - val_loss: 641384.5000 - 49ms/epoch - 1ms/step
# Epoch 98/10000
#
# Epoch 00098: val_loss improved from 641384.50000 to 640152.62500, saving model to ./model\98-640152.6250.hdf5
# 35/35 - 0s - loss: 503514.8750 - val_loss: 640152.6250 - 57ms/epoch - 2ms/step
# Epoch 99/10000
#
# Epoch 00099: val_loss improved from 640152.62500 to 638976.37500, saving model to ./model\99-638976.3750.hdf5
# 35/35 - 0s - loss: 502383.5000 - val_loss: 638976.3750 - 51ms/epoch - 1ms/step
# Epoch 100/10000
#
# Epoch 00100: val_loss improved from 638976.37500 to 638038.81250, saving model to ./model\100-638038.8125.hdf5
# 35/35 - 0s - loss: 501254.6875 - val_loss: 638038.8125 - 57ms/epoch - 2ms/step
# Epoch 101/10000
#
# Epoch 00101: val_loss improved from 638038.81250 to 636660.31250, saving model to ./model\101-636660.3125.hdf5
# 35/35 - 0s - loss: 500167.1562 - val_loss: 636660.3125 - 45ms/epoch - 1ms/step
# Epoch 102/10000
#
# Epoch 00102: val_loss improved from 636660.31250 to 635377.68750, saving model to ./model\102-635377.6875.hdf5
# 35/35 - 0s - loss: 499062.5000 - val_loss: 635377.6875 - 60ms/epoch - 2ms/step
# Epoch 103/10000
#
# Epoch 00103: val_loss improved from 635377.68750 to 634355.31250, saving model to ./model\103-634355.3125.hdf5
# 35/35 - 0s - loss: 498017.9062 - val_loss: 634355.3125 - 54ms/epoch - 2ms/step
# Epoch 104/10000
#
# Epoch 00104: val_loss improved from 634355.31250 to 633160.06250, saving model to ./model\104-633160.0625.hdf5
# 35/35 - 0s - loss: 496918.7812 - val_loss: 633160.0625 - 54ms/epoch - 2ms/step
# Epoch 105/10000
#
# Epoch 00105: val_loss improved from 633160.06250 to 632356.12500, saving model to ./model\105-632356.1250.hdf5
# 35/35 - 0s - loss: 495958.0312 - val_loss: 632356.1250 - 52ms/epoch - 1ms/step
# Epoch 106/10000
#
# Epoch 00106: val_loss improved from 632356.12500 to 630733.12500, saving model to ./model\106-630733.1250.hdf5
# 35/35 - 0s - loss: 494879.8750 - val_loss: 630733.1250 - 62ms/epoch - 2ms/step
# Epoch 107/10000
#
# Epoch 00107: val_loss improved from 630733.12500 to 629825.37500, saving model to ./model\107-629825.3750.hdf5
# 35/35 - 0s - loss: 493823.8125 - val_loss: 629825.3750 - 56ms/epoch - 2ms/step
# Epoch 108/10000
#
# Epoch 00108: val_loss improved from 629825.37500 to 628884.81250, saving model to ./model\108-628884.8125.hdf5
# 35/35 - 0s - loss: 492834.4688 - val_loss: 628884.8125 - 50ms/epoch - 1ms/step
# Epoch 109/10000
#
# Epoch 00109: val_loss improved from 628884.81250 to 627653.37500, saving model to ./model\109-627653.3750.hdf5
# 35/35 - 0s - loss: 491795.0938 - val_loss: 627653.3750 - 53ms/epoch - 2ms/step
# Epoch 110/10000
#
# Epoch 00110: val_loss improved from 627653.37500 to 626363.18750, saving model to ./model\110-626363.1875.hdf5
# 35/35 - 0s - loss: 490895.3438 - val_loss: 626363.1875 - 51ms/epoch - 1ms/step
# Epoch 111/10000
#
# Epoch 00111: val_loss improved from 626363.18750 to 625419.75000, saving model to ./model\111-625419.7500.hdf5
# 35/35 - 0s - loss: 489932.0000 - val_loss: 625419.7500 - 51ms/epoch - 1ms/step
# Epoch 112/10000
#
# Epoch 00112: val_loss improved from 625419.75000 to 624431.75000, saving model to ./model\112-624431.7500.hdf5
# 35/35 - 0s - loss: 488959.8750 - val_loss: 624431.7500 - 54ms/epoch - 2ms/step
# Epoch 113/10000
#
# Epoch 00113: val_loss improved from 624431.75000 to 623422.31250, saving model to ./model\113-623422.3125.hdf5
# 35/35 - 0s - loss: 488022.1250 - val_loss: 623422.3125 - 56ms/epoch - 2ms/step
# Epoch 114/10000
#
# Epoch 00114: val_loss improved from 623422.31250 to 622556.93750, saving model to ./model\114-622556.9375.hdf5
# 35/35 - 0s - loss: 487193.3125 - val_loss: 622556.9375 - 57ms/epoch - 2ms/step
# Epoch 115/10000
#
# Epoch 00115: val_loss improved from 622556.93750 to 621604.25000, saving model to ./model\115-621604.2500.hdf5
# 35/35 - 0s - loss: 486355.5312 - val_loss: 621604.2500 - 51ms/epoch - 1ms/step
# Epoch 116/10000
#
# Epoch 00116: val_loss improved from 621604.25000 to 620385.75000, saving model to ./model\116-620385.7500.hdf5
# 35/35 - 0s - loss: 485396.3438 - val_loss: 620385.7500 - 52ms/epoch - 1ms/step
# Epoch 117/10000
#
# Epoch 00117: val_loss improved from 620385.75000 to 619326.25000, saving model to ./model\117-619326.2500.hdf5
# 35/35 - 0s - loss: 484578.5312 - val_loss: 619326.2500 - 51ms/epoch - 1ms/step
# Epoch 118/10000
#
# Epoch 00118: val_loss improved from 619326.25000 to 618429.18750, saving model to ./model\118-618429.1875.hdf5
# 35/35 - 0s - loss: 483871.0625 - val_loss: 618429.1875 - 54ms/epoch - 2ms/step
# Epoch 119/10000
#
# Epoch 00119: val_loss improved from 618429.18750 to 617274.62500, saving model to ./model\119-617274.6250.hdf5
# 35/35 - 0s - loss: 482996.5625 - val_loss: 617274.6250 - 48ms/epoch - 1ms/step
# Epoch 120/10000
#
# Epoch 00120: val_loss improved from 617274.62500 to 616700.81250, saving model to ./model\120-616700.8125.hdf5
# 35/35 - 0s - loss: 482139.5625 - val_loss: 616700.8125 - 54ms/epoch - 2ms/step
# Epoch 121/10000
#
# Epoch 00121: val_loss improved from 616700.81250 to 615692.50000, saving model to ./model\121-615692.5000.hdf5
# 35/35 - 0s - loss: 481386.6562 - val_loss: 615692.5000 - 58ms/epoch - 2ms/step
# Epoch 122/10000
#
# Epoch 00122: val_loss improved from 615692.50000 to 615016.93750, saving model to ./model\122-615016.9375.hdf5
# 35/35 - 0s - loss: 480665.8438 - val_loss: 615016.9375 - 56ms/epoch - 2ms/step
# Epoch 123/10000
#
# Epoch 00123: val_loss improved from 615016.93750 to 614140.75000, saving model to ./model\123-614140.7500.hdf5
# 35/35 - 0s - loss: 479863.0938 - val_loss: 614140.7500 - 55ms/epoch - 2ms/step
# Epoch 124/10000
#
# Epoch 00124: val_loss improved from 614140.75000 to 613198.50000, saving model to ./model\124-613198.5000.hdf5
# 35/35 - 0s - loss: 479161.9688 - val_loss: 613198.5000 - 49ms/epoch - 1ms/step
# Epoch 125/10000
#
# Epoch 00125: val_loss improved from 613198.50000 to 612248.75000, saving model to ./model\125-612248.7500.hdf5
# 35/35 - 0s - loss: 478458.6875 - val_loss: 612248.7500 - 52ms/epoch - 1ms/step
# Epoch 126/10000
#
# Epoch 00126: val_loss improved from 612248.75000 to 611692.43750, saving model to ./model\126-611692.4375.hdf5
# 35/35 - 0s - loss: 477770.5625 - val_loss: 611692.4375 - 55ms/epoch - 2ms/step
# Epoch 127/10000
#
# Epoch 00127: val_loss improved from 611692.43750 to 610852.25000, saving model to ./model\127-610852.2500.hdf5
# 35/35 - 0s - loss: 477081.9688 - val_loss: 610852.2500 - 56ms/epoch - 2ms/step
# Epoch 128/10000
#
# Epoch 00128: val_loss improved from 610852.25000 to 610007.62500, saving model to ./model\128-610007.6250.hdf5
# 35/35 - 0s - loss: 476446.5312 - val_loss: 610007.6250 - 47ms/epoch - 1ms/step
# Epoch 129/10000
#
# Epoch 00129: val_loss improved from 610007.62500 to 609118.06250, saving model to ./model\129-609118.0625.hdf5
# 35/35 - 0s - loss: 475858.6562 - val_loss: 609118.0625 - 49ms/epoch - 1ms/step
# Epoch 130/10000
#
# Epoch 00130: val_loss improved from 609118.06250 to 608910.37500, saving model to ./model\130-608910.3750.hdf5
# 35/35 - 0s - loss: 475239.2188 - val_loss: 608910.3750 - 55ms/epoch - 2ms/step
# Epoch 131/10000
#
# Epoch 00131: val_loss improved from 608910.37500 to 607801.00000, saving model to ./model\131-607801.0000.hdf5
# 35/35 - 0s - loss: 474762.6250 - val_loss: 607801.0000 - 50ms/epoch - 1ms/step
# Epoch 132/10000
#
# Epoch 00132: val_loss improved from 607801.00000 to 607409.18750, saving model to ./model\132-607409.1875.hdf5
# 35/35 - 0s - loss: 474017.5312 - val_loss: 607409.1875 - 52ms/epoch - 1ms/step
# Epoch 133/10000
#
# Epoch 00133: val_loss improved from 607409.18750 to 606379.25000, saving model to ./model\133-606379.2500.hdf5
# 35/35 - 0s - loss: 473503.5938 - val_loss: 606379.2500 - 50ms/epoch - 1ms/step
# Epoch 134/10000
#
# Epoch 00134: val_loss improved from 606379.25000 to 606158.81250, saving model to ./model\134-606158.8125.hdf5
# 35/35 - 0s - loss: 472948.1875 - val_loss: 606158.8125 - 58ms/epoch - 2ms/step
# Epoch 135/10000
#
# Epoch 00135: val_loss improved from 606158.81250 to 605306.93750, saving model to ./model\135-605306.9375.hdf5
# 35/35 - 0s - loss: 472468.1250 - val_loss: 605306.9375 - 52ms/epoch - 1ms/step
# Epoch 136/10000
#
# Epoch 00136: val_loss improved from 605306.93750 to 604701.62500, saving model to ./model\136-604701.6250.hdf5
# 35/35 - 0s - loss: 471886.6875 - val_loss: 604701.6250 - 48ms/epoch - 1ms/step
# Epoch 137/10000
#
# Epoch 00137: val_loss improved from 604701.62500 to 604253.31250, saving model to ./model\137-604253.3125.hdf5
# 35/35 - 0s - loss: 471513.8750 - val_loss: 604253.3125 - 49ms/epoch - 1ms/step
# Epoch 138/10000
#
# Epoch 00138: val_loss improved from 604253.31250 to 603226.12500, saving model to ./model\138-603226.1250.hdf5
# 35/35 - 0s - loss: 470920.8438 - val_loss: 603226.1250 - 48ms/epoch - 1ms/step
# Epoch 139/10000
#
# Epoch 00139: val_loss improved from 603226.12500 to 602998.50000, saving model to ./model\139-602998.5000.hdf5
# 35/35 - 0s - loss: 470465.4062 - val_loss: 602998.5000 - 47ms/epoch - 1ms/step
# Epoch 140/10000
#
# Epoch 00140: val_loss improved from 602998.50000 to 602242.37500, saving model to ./model\140-602242.3750.hdf5
# 35/35 - 0s - loss: 469996.8125 - val_loss: 602242.3750 - 55ms/epoch - 2ms/step
# Epoch 141/10000
#
# Epoch 00141: val_loss improved from 602242.37500 to 601865.68750, saving model to ./model\141-601865.6875.hdf5
# 35/35 - 0s - loss: 469576.5938 - val_loss: 601865.6875 - 57ms/epoch - 2ms/step
# Epoch 142/10000
#
# Epoch 00142: val_loss improved from 601865.68750 to 601140.81250, saving model to ./model\142-601140.8125.hdf5
# 35/35 - 0s - loss: 469148.2500 - val_loss: 601140.8125 - 56ms/epoch - 2ms/step
# Epoch 143/10000
#
# Epoch 00143: val_loss improved from 601140.81250 to 600580.31250, saving model to ./model\143-600580.3125.hdf5
# 35/35 - 0s - loss: 468766.7812 - val_loss: 600580.3125 - 59ms/epoch - 2ms/step
# Epoch 144/10000
#
# Epoch 00144: val_loss improved from 600580.31250 to 600024.18750, saving model to ./model\144-600024.1875.hdf5
# 35/35 - 0s - loss: 468344.0312 - val_loss: 600024.1875 - 50ms/epoch - 1ms/step
# Epoch 145/10000
#
# Epoch 00145: val_loss improved from 600024.18750 to 599777.93750, saving model to ./model\145-599777.9375.hdf5
# 35/35 - 0s - loss: 467854.2188 - val_loss: 599777.9375 - 53ms/epoch - 2ms/step
# Epoch 146/10000
#
# Epoch 00146: val_loss improved from 599777.93750 to 599305.43750, saving model to ./model\146-599305.4375.hdf5
# 35/35 - 0s - loss: 467501.7812 - val_loss: 599305.4375 - 53ms/epoch - 2ms/step
# Epoch 147/10000
#
# Epoch 00147: val_loss improved from 599305.43750 to 599034.12500, saving model to ./model\147-599034.1250.hdf5
# 35/35 - 0s - loss: 467121.5000 - val_loss: 599034.1250 - 50ms/epoch - 1ms/step
# Epoch 148/10000
#
# Epoch 00148: val_loss improved from 599034.12500 to 598283.56250, saving model to ./model\148-598283.5625.hdf5
# 35/35 - 0s - loss: 466867.8750 - val_loss: 598283.5625 - 52ms/epoch - 1ms/step
# Epoch 149/10000
#
# Epoch 00149: val_loss improved from 598283.56250 to 597881.25000, saving model to ./model\149-597881.2500.hdf5
# 35/35 - 0s - loss: 466392.9062 - val_loss: 597881.2500 - 53ms/epoch - 2ms/step
# Epoch 150/10000
#
# Epoch 00150: val_loss improved from 597881.25000 to 597478.93750, saving model to ./model\150-597478.9375.hdf5
# 35/35 - 0s - loss: 466080.4688 - val_loss: 597478.9375 - 66ms/epoch - 2ms/step
# Epoch 151/10000
#
# Epoch 00151: val_loss improved from 597478.93750 to 597240.00000, saving model to ./model\151-597240.0000.hdf5
# 35/35 - 0s - loss: 465788.1875 - val_loss: 597240.0000 - 52ms/epoch - 1ms/step
# Epoch 152/10000
#
# Epoch 00152: val_loss improved from 597240.00000 to 596893.56250, saving model to ./model\152-596893.5625.hdf5
# 35/35 - 0s - loss: 465501.0312 - val_loss: 596893.5625 - 51ms/epoch - 1ms/step
# Epoch 153/10000
#
# Epoch 00153: val_loss improved from 596893.56250 to 595697.25000, saving model to ./model\153-595697.2500.hdf5
# 35/35 - 0s - loss: 465194.5938 - val_loss: 595697.2500 - 51ms/epoch - 1ms/step
# Epoch 154/10000
#
# Epoch 00154: val_loss did not improve from 595697.25000
# 35/35 - 0s - loss: 464832.7812 - val_loss: 595708.9375 - 47ms/epoch - 1ms/step
# Epoch 155/10000
#
# Epoch 00155: val_loss improved from 595697.25000 to 595398.87500, saving model to ./model\155-595398.8750.hdf5
# 35/35 - 0s - loss: 464540.2500 - val_loss: 595398.8750 - 57ms/epoch - 2ms/step
# Epoch 156/10000
#
# Epoch 00156: val_loss improved from 595398.87500 to 595173.62500, saving model to ./model\156-595173.6250.hdf5
# 35/35 - 0s - loss: 464262.6875 - val_loss: 595173.6250 - 49ms/epoch - 1ms/step
# Epoch 157/10000
#
# Epoch 00157: val_loss improved from 595173.62500 to 594615.12500, saving model to ./model\157-594615.1250.hdf5
# 35/35 - 0s - loss: 463972.2812 - val_loss: 594615.1250 - 57ms/epoch - 2ms/step
# Epoch 158/10000
#
# Epoch 00158: val_loss improved from 594615.12500 to 594078.75000, saving model to ./model\158-594078.7500.hdf5
# 35/35 - 0s - loss: 463677.5625 - val_loss: 594078.7500 - 52ms/epoch - 1ms/step
# Epoch 159/10000
#
# Epoch 00159: val_loss improved from 594078.75000 to 594062.62500, saving model to ./model\159-594062.6250.hdf5
# 35/35 - 0s - loss: 463511.8750 - val_loss: 594062.6250 - 58ms/epoch - 2ms/step
# Epoch 160/10000
#
# Epoch 00160: val_loss improved from 594062.62500 to 593360.50000, saving model to ./model\160-593360.5000.hdf5
# 35/35 - 0s - loss: 463145.5625 - val_loss: 593360.5000 - 52ms/epoch - 1ms/step
# Epoch 161/10000
#
# Epoch 00161: val_loss improved from 593360.50000 to 593099.31250, saving model to ./model\161-593099.3125.hdf5
# 35/35 - 0s - loss: 463018.9062 - val_loss: 593099.3125 - 55ms/epoch - 2ms/step
# Epoch 162/10000
#
# Epoch 00162: val_loss improved from 593099.31250 to 592696.25000, saving model to ./model\162-592696.2500.hdf5
# 35/35 - 0s - loss: 462636.7188 - val_loss: 592696.2500 - 55ms/epoch - 2ms/step
# Epoch 163/10000
#
# Epoch 00163: val_loss improved from 592696.25000 to 592467.25000, saving model to ./model\163-592467.2500.hdf5
# 35/35 - 0s - loss: 462420.9062 - val_loss: 592467.2500 - 54ms/epoch - 2ms/step
# Epoch 164/10000
#
# Epoch 00164: val_loss improved from 592467.25000 to 592288.62500, saving model to ./model\164-592288.6250.hdf5
# 35/35 - 0s - loss: 462170.2188 - val_loss: 592288.6250 - 52ms/epoch - 1ms/step
# Epoch 165/10000
#
# Epoch 00165: val_loss improved from 592288.62500 to 591985.56250, saving model to ./model\165-591985.5625.hdf5
# 35/35 - 0s - loss: 461912.6875 - val_loss: 591985.5625 - 54ms/epoch - 2ms/step
# Epoch 166/10000
#
# Epoch 00166: val_loss improved from 591985.56250 to 591479.81250, saving model to ./model\166-591479.8125.hdf5
# 35/35 - 0s - loss: 461857.6875 - val_loss: 591479.8125 - 51ms/epoch - 1ms/step
# Epoch 167/10000
#
# Epoch 00167: val_loss improved from 591479.81250 to 591393.43750, saving model to ./model\167-591393.4375.hdf5
# 35/35 - 0s - loss: 461468.8438 - val_loss: 591393.4375 - 56ms/epoch - 2ms/step
# Epoch 168/10000
#
# Epoch 00168: val_loss improved from 591393.43750 to 590961.87500, saving model to ./model\168-590961.8750.hdf5
# 35/35 - 0s - loss: 461234.9688 - val_loss: 590961.8750 - 55ms/epoch - 2ms/step
# Epoch 169/10000
#
# Epoch 00169: val_loss improved from 590961.87500 to 590725.68750, saving model to ./model\169-590725.6875.hdf5
# 35/35 - 0s - loss: 461038.7812 - val_loss: 590725.6875 - 56ms/epoch - 2ms/step
# Epoch 170/10000
#
# Epoch 00170: val_loss improved from 590725.68750 to 590315.75000, saving model to ./model\170-590315.7500.hdf5
# 35/35 - 0s - loss: 460850.5625 - val_loss: 590315.7500 - 55ms/epoch - 2ms/step
# Epoch 171/10000
#
# Epoch 00171: val_loss improved from 590315.75000 to 590167.62500, saving model to ./model\171-590167.6250.hdf5
# 35/35 - 0s - loss: 460667.9688 - val_loss: 590167.6250 - 55ms/epoch - 2ms/step
# Epoch 172/10000
#
# Epoch 00172: val_loss improved from 590167.62500 to 589754.43750, saving model to ./model\172-589754.4375.hdf5
# 35/35 - 0s - loss: 460452.0938 - val_loss: 589754.4375 - 51ms/epoch - 1ms/step
# Epoch 173/10000
#
# Epoch 00173: val_loss improved from 589754.43750 to 589682.31250, saving model to ./model\173-589682.3125.hdf5
# 35/35 - 0s - loss: 460243.2188 - val_loss: 589682.3125 - 52ms/epoch - 1ms/step
# Epoch 174/10000
#
# Epoch 00174: val_loss improved from 589682.31250 to 589384.50000, saving model to ./model\174-589384.5000.hdf5
# 35/35 - 0s - loss: 460039.0000 - val_loss: 589384.5000 - 51ms/epoch - 1ms/step
# Epoch 175/10000
#
# Epoch 00175: val_loss improved from 589384.50000 to 588898.93750, saving model to ./model\175-588898.9375.hdf5
# 35/35 - 0s - loss: 459918.4688 - val_loss: 588898.9375 - 50ms/epoch - 1ms/step
# Epoch 176/10000
#
# Epoch 00176: val_loss improved from 588898.93750 to 588615.31250, saving model to ./model\176-588615.3125.hdf5
# 35/35 - 0s - loss: 459647.4375 - val_loss: 588615.3125 - 52ms/epoch - 1ms/step
# Epoch 177/10000
#
# Epoch 00177: val_loss improved from 588615.31250 to 588560.68750, saving model to ./model\177-588560.6875.hdf5
# 35/35 - 0s - loss: 459458.1562 - val_loss: 588560.6875 - 53ms/epoch - 2ms/step
# Epoch 178/10000
#
# Epoch 00178: val_loss improved from 588560.68750 to 588090.62500, saving model to ./model\178-588090.6250.hdf5
# 35/35 - 0s - loss: 459266.8438 - val_loss: 588090.6250 - 49ms/epoch - 1ms/step
# Epoch 179/10000
#
# Epoch 00179: val_loss improved from 588090.62500 to 587650.75000, saving model to ./model\179-587650.7500.hdf5
# 35/35 - 0s - loss: 459127.4062 - val_loss: 587650.7500 - 54ms/epoch - 2ms/step
# Epoch 180/10000
#
# Epoch 00180: val_loss did not improve from 587650.75000
# 35/35 - 0s - loss: 459092.7812 - val_loss: 588138.3750 - 44ms/epoch - 1ms/step
# Epoch 181/10000
#
# Epoch 00181: val_loss improved from 587650.75000 to 587322.68750, saving model to ./model\181-587322.6875.hdf5
# 35/35 - 0s - loss: 458768.8438 - val_loss: 587322.6875 - 60ms/epoch - 2ms/step
# Epoch 182/10000
#
# Epoch 00182: val_loss improved from 587322.68750 to 586756.81250, saving model to ./model\182-586756.8125.hdf5
# 35/35 - 0s - loss: 458642.7188 - val_loss: 586756.8125 - 53ms/epoch - 2ms/step
# Epoch 183/10000
#
# Epoch 00183: val_loss did not improve from 586756.81250
# 35/35 - 0s - loss: 458520.8438 - val_loss: 587228.3125 - 40ms/epoch - 1ms/step
# Epoch 184/10000
#
# Epoch 00184: val_loss did not improve from 586756.81250
# 35/35 - 0s - loss: 458243.7500 - val_loss: 586978.3125 - 37ms/epoch - 1ms/step
# Epoch 185/10000
#
# Epoch 00185: val_loss improved from 586756.81250 to 586610.75000, saving model to ./model\185-586610.7500.hdf5
# 35/35 - 0s - loss: 458078.1562 - val_loss: 586610.7500 - 52ms/epoch - 1ms/step
# Epoch 186/10000
#
# Epoch 00186: val_loss improved from 586610.75000 to 585941.81250, saving model to ./model\186-585941.8125.hdf5
# 35/35 - 0s - loss: 457888.1875 - val_loss: 585941.8125 - 58ms/epoch - 2ms/step
# Epoch 187/10000
#
# Epoch 00187: val_loss did not improve from 585941.81250
# 35/35 - 0s - loss: 457729.5000 - val_loss: 585996.0625 - 42ms/epoch - 1ms/step
# Epoch 188/10000
#
# Epoch 00188: val_loss improved from 585941.81250 to 585746.68750, saving model to ./model\188-585746.6875.hdf5
# 35/35 - 0s - loss: 457589.6875 - val_loss: 585746.6875 - 59ms/epoch - 2ms/step
# Epoch 189/10000
#
# Epoch 00189: val_loss improved from 585746.68750 to 585634.18750, saving model to ./model\189-585634.1875.hdf5
# 35/35 - 0s - loss: 457448.9375 - val_loss: 585634.1875 - 54ms/epoch - 2ms/step
# Epoch 190/10000
#
# Epoch 00190: val_loss improved from 585634.18750 to 585031.12500, saving model to ./model\190-585031.1250.hdf5
# 35/35 - 0s - loss: 457344.0938 - val_loss: 585031.1250 - 59ms/epoch - 2ms/step
# Epoch 191/10000
#
# Epoch 00191: val_loss did not improve from 585031.12500
# 35/35 - 0s - loss: 457421.8438 - val_loss: 585138.5625 - 44ms/epoch - 1ms/step
# Epoch 192/10000
#
# Epoch 00192: val_loss improved from 585031.12500 to 584706.37500, saving model to ./model\192-584706.3750.hdf5
# 35/35 - 0s - loss: 457036.2500 - val_loss: 584706.3750 - 52ms/epoch - 1ms/step
# Epoch 193/10000
#
# Epoch 00193: val_loss improved from 584706.37500 to 584695.87500, saving model to ./model\193-584695.8750.hdf5
# 35/35 - 0s - loss: 456837.5000 - val_loss: 584695.8750 - 55ms/epoch - 2ms/step
# Epoch 194/10000
#
# Epoch 00194: val_loss improved from 584695.87500 to 584451.50000, saving model to ./model\194-584451.5000.hdf5
# 35/35 - 0s - loss: 456680.6562 - val_loss: 584451.5000 - 46ms/epoch - 1ms/step
# Epoch 195/10000
#
# Epoch 00195: val_loss improved from 584451.50000 to 584332.62500, saving model to ./model\195-584332.6250.hdf5
# 35/35 - 0s - loss: 456545.3125 - val_loss: 584332.6250 - 53ms/epoch - 2ms/step
# Epoch 196/10000
#
# Epoch 00196: val_loss improved from 584332.62500 to 583945.43750, saving model to ./model\196-583945.4375.hdf5
# 35/35 - 0s - loss: 456343.2500 - val_loss: 583945.4375 - 51ms/epoch - 1ms/step
# Epoch 197/10000
#
# Epoch 00197: val_loss improved from 583945.43750 to 583814.81250, saving model to ./model\197-583814.8125.hdf5
# 35/35 - 0s - loss: 456177.9688 - val_loss: 583814.8125 - 50ms/epoch - 1ms/step
# Epoch 198/10000
#
# Epoch 00198: val_loss improved from 583814.81250 to 583763.62500, saving model to ./model\198-583763.6250.hdf5
# 35/35 - 0s - loss: 456059.5312 - val_loss: 583763.6250 - 57ms/epoch - 2ms/step
# Epoch 199/10000
#
# Epoch 00199: val_loss improved from 583763.62500 to 583250.43750, saving model to ./model\199-583250.4375.hdf5
# 35/35 - 0s - loss: 455950.7188 - val_loss: 583250.4375 - 50ms/epoch - 1ms/step
# Epoch 200/10000
#
# Epoch 00200: val_loss did not improve from 583250.43750
# 35/35 - 0s - loss: 455746.1562 - val_loss: 583273.5625 - 43ms/epoch - 1ms/step
# Epoch 201/10000
#
# Epoch 00201: val_loss improved from 583250.43750 to 582993.43750, saving model to ./model\201-582993.4375.hdf5
# 35/35 - 0s - loss: 455580.5312 - val_loss: 582993.4375 - 59ms/epoch - 2ms/step
# Epoch 202/10000
#
# Epoch 00202: val_loss improved from 582993.43750 to 582891.87500, saving model to ./model\202-582891.8750.hdf5
# 35/35 - 0s - loss: 455454.4062 - val_loss: 582891.8750 - 54ms/epoch - 2ms/step
# Epoch 203/10000
#
# Epoch 00203: val_loss improved from 582891.87500 to 582640.37500, saving model to ./model\203-582640.3750.hdf5
# 35/35 - 0s - loss: 455289.8438 - val_loss: 582640.3750 - 50ms/epoch - 1ms/step
# Epoch 204/10000
#
# Epoch 00204: val_loss improved from 582640.37500 to 582245.87500, saving model to ./model\204-582245.8750.hdf5
# 35/35 - 0s - loss: 455249.6875 - val_loss: 582245.8750 - 53ms/epoch - 2ms/step
# Epoch 205/10000
#
# Epoch 00205: val_loss did not improve from 582245.87500
# 35/35 - 0s - loss: 455150.6875 - val_loss: 582492.0625 - 46ms/epoch - 1ms/step
# Epoch 206/10000
#
# Epoch 00206: val_loss improved from 582245.87500 to 581919.37500, saving model to ./model\206-581919.3750.hdf5
# 35/35 - 0s - loss: 454872.3438 - val_loss: 581919.3750 - 52ms/epoch - 1ms/step
# Epoch 207/10000
#
# Epoch 00207: val_loss improved from 581919.37500 to 581633.62500, saving model to ./model\207-581633.6250.hdf5
# 35/35 - 0s - loss: 454779.7188 - val_loss: 581633.6250 - 59ms/epoch - 2ms/step
# Epoch 208/10000
#
# Epoch 00208: val_loss did not improve from 581633.62500
# 35/35 - 0s - loss: 454612.2812 - val_loss: 581665.0000 - 44ms/epoch - 1ms/step
# Epoch 209/10000
#
# Epoch 00209: val_loss improved from 581633.62500 to 581583.06250, saving model to ./model\209-581583.0625.hdf5
# 35/35 - 0s - loss: 454451.5312 - val_loss: 581583.0625 - 57ms/epoch - 2ms/step
# Epoch 210/10000
#
# Epoch 00210: val_loss improved from 581583.06250 to 581504.81250, saving model to ./model\210-581504.8125.hdf5
# 35/35 - 0s - loss: 454411.2500 - val_loss: 581504.8125 - 57ms/epoch - 2ms/step
# Epoch 211/10000
#
# Epoch 00211: val_loss improved from 581504.81250 to 581039.43750, saving model to ./model\211-581039.4375.hdf5
# 35/35 - 0s - loss: 454337.8125 - val_loss: 581039.4375 - 55ms/epoch - 2ms/step
# Epoch 212/10000
#
# Epoch 00212: val_loss did not improve from 581039.43750
# 35/35 - 0s - loss: 454100.8125 - val_loss: 581178.3125 - 50ms/epoch - 1ms/step
# Epoch 213/10000
#
# Epoch 00213: val_loss improved from 581039.43750 to 581009.93750, saving model to ./model\213-581009.9375.hdf5
# 35/35 - 0s - loss: 453912.0312 - val_loss: 581009.9375 - 53ms/epoch - 2ms/step
# Epoch 214/10000
#
# Epoch 00214: val_loss improved from 581009.93750 to 580507.50000, saving model to ./model\214-580507.5000.hdf5
# 35/35 - 0s - loss: 453820.1875 - val_loss: 580507.5000 - 53ms/epoch - 2ms/step
# Epoch 215/10000
#
# Epoch 00215: val_loss improved from 580507.50000 to 580352.12500, saving model to ./model\215-580352.1250.hdf5
# 35/35 - 0s - loss: 453638.0625 - val_loss: 580352.1250 - 57ms/epoch - 2ms/step
# Epoch 216/10000
#
# Epoch 00216: val_loss did not improve from 580352.12500
# 35/35 - 0s - loss: 453533.1250 - val_loss: 580374.7500 - 43ms/epoch - 1ms/step
# Epoch 217/10000
#
# Epoch 00217: val_loss improved from 580352.12500 to 580079.87500, saving model to ./model\217-580079.8750.hdf5
# 35/35 - 0s - loss: 453353.6875 - val_loss: 580079.8750 - 59ms/epoch - 2ms/step
# Epoch 218/10000
#
# Epoch 00218: val_loss improved from 580079.87500 to 579735.50000, saving model to ./model\218-579735.5000.hdf5
# 35/35 - 0s - loss: 453259.2188 - val_loss: 579735.5000 - 55ms/epoch - 2ms/step
# Epoch 219/10000
#
# Epoch 00219: val_loss did not improve from 579735.50000
# 35/35 - 0s - loss: 453197.5938 - val_loss: 579761.0000 - 45ms/epoch - 1ms/step
# Epoch 220/10000
#
# Epoch 00220: val_loss improved from 579735.50000 to 579563.81250, saving model to ./model\220-579563.8125.hdf5
# 35/35 - 0s - loss: 452991.7188 - val_loss: 579563.8125 - 57ms/epoch - 2ms/step
# Epoch 221/10000
#
# Epoch 00221: val_loss improved from 579563.81250 to 579446.75000, saving model to ./model\221-579446.7500.hdf5
# 35/35 - 0s - loss: 452847.9062 - val_loss: 579446.7500 - 57ms/epoch - 2ms/step
# Epoch 222/10000
#
# Epoch 00222: val_loss improved from 579446.75000 to 579287.37500, saving model to ./model\222-579287.3750.hdf5
# 35/35 - 0s - loss: 452694.6562 - val_loss: 579287.3750 - 50ms/epoch - 1ms/step
# Epoch 223/10000
#
# Epoch 00223: val_loss improved from 579287.37500 to 579025.06250, saving model to ./model\223-579025.0625.hdf5
# 35/35 - 0s - loss: 452566.5000 - val_loss: 579025.0625 - 51ms/epoch - 1ms/step
# Epoch 224/10000
#
# Epoch 00224: val_loss did not improve from 579025.06250
# 35/35 - 0s - loss: 452454.6250 - val_loss: 579057.1250 - 47ms/epoch - 1ms/step
# Epoch 225/10000
#
# Epoch 00225: val_loss improved from 579025.06250 to 578797.43750, saving model to ./model\225-578797.4375.hdf5
# 35/35 - 0s - loss: 452348.0312 - val_loss: 578797.4375 - 51ms/epoch - 1ms/step
# Epoch 226/10000
#
# Epoch 00226: val_loss improved from 578797.43750 to 578624.00000, saving model to ./model\226-578624.0000.hdf5
# 35/35 - 0s - loss: 452180.1250 - val_loss: 578624.0000 - 55ms/epoch - 2ms/step
# Epoch 227/10000
#
# Epoch 00227: val_loss improved from 578624.00000 to 578153.93750, saving model to ./model\227-578153.9375.hdf5
# 35/35 - 0s - loss: 452090.0312 - val_loss: 578153.9375 - 54ms/epoch - 2ms/step
# Epoch 228/10000
#
# Epoch 00228: val_loss improved from 578153.93750 to 578115.81250, saving model to ./model\228-578115.8125.hdf5
# 35/35 - 0s - loss: 451872.0938 - val_loss: 578115.8125 - 54ms/epoch - 2ms/step
# Epoch 229/10000
#
# Epoch 00229: val_loss improved from 578115.81250 to 578041.81250, saving model to ./model\229-578041.8125.hdf5
# 35/35 - 0s - loss: 451791.0000 - val_loss: 578041.8125 - 50ms/epoch - 1ms/step
# Epoch 230/10000
#
# Epoch 00230: val_loss improved from 578041.81250 to 577749.25000, saving model to ./model\230-577749.2500.hdf5
# 35/35 - 0s - loss: 451609.8750 - val_loss: 577749.2500 - 52ms/epoch - 1ms/step
# Epoch 231/10000
#
# Epoch 00231: val_loss improved from 577749.25000 to 577630.87500, saving model to ./model\231-577630.8750.hdf5
# 35/35 - 0s - loss: 451456.5625 - val_loss: 577630.8750 - 52ms/epoch - 1ms/step
# Epoch 232/10000
#
# Epoch 00232: val_loss improved from 577630.87500 to 577477.25000, saving model to ./model\232-577477.2500.hdf5
# 35/35 - 0s - loss: 451397.6875 - val_loss: 577477.2500 - 51ms/epoch - 1ms/step
# Epoch 233/10000
#
# Epoch 00233: val_loss did not improve from 577477.25000
# 35/35 - 0s - loss: 451280.8750 - val_loss: 577694.8125 - 46ms/epoch - 1ms/step
# Epoch 234/10000
#
# Epoch 00234: val_loss improved from 577477.25000 to 577173.43750, saving model to ./model\234-577173.4375.hdf5
# 35/35 - 0s - loss: 451082.8438 - val_loss: 577173.4375 - 53ms/epoch - 2ms/step
# Epoch 235/10000
#
# Epoch 00235: val_loss improved from 577173.43750 to 576941.06250, saving model to ./model\235-576941.0625.hdf5
# 35/35 - 0s - loss: 450982.9688 - val_loss: 576941.0625 - 57ms/epoch - 2ms/step
# Epoch 236/10000
#
# Epoch 00236: val_loss improved from 576941.06250 to 576617.25000, saving model to ./model\236-576617.2500.hdf5
# ...
# Epoch 4298/10000
#
# Epoch 04298: val_loss did not improve from 436783.50000
# 35/35 - 0s - loss: 335847.1562 - val_loss: 437010.6562 - 44ms/epoch - 1ms/step
# Epoch 4299/10000
#
# Epoch 04299: val_loss did not improve from 436783.50000
# 35/35 - 0s - loss: 335889.3125 - val_loss: 437038.1250 - 39ms/epoch - 1ms/step
# Epoch 4300/10000
#
# Epoch 04300: val_loss did not improve from 436783.50000
# 35/35 - 0s - loss: 335858.8125 - val_loss: 437093.7812 - 44ms/epoch - 1ms/step
# Epoch 4301/10000
#
# Epoch 04301: val_loss did not improve from 436783.50000
# 35/35 - 0s - loss: 336003.6875 - val_loss: 436888.0625 - 38ms/epoch - 1ms/step
# Epoch 4302/10000
#
# Epoch 04302: val_loss did not improve from 436783.50000
# 35/35 - 0s - loss: 336116.4375 - val_loss: 437251.6562 - 45ms/epoch - 1ms/step
# Epoch 4303/10000
#
# Epoch 04303: val_loss improved from 436783.50000 to 436764.71875, saving model to ./model\4303-436764.7188.hdf5
# 35/35 - 0s - loss: 335930.0625 - val_loss: 436764.7188 - 55ms/epoch - 2ms/step
# Epoch 4304/10000
#
# Epoch 04304: val_loss did not improve from 436764.71875
# 35/35 - 0s - loss: 336339.3438 - val_loss: 437028.6250 - 40ms/epoch - 1ms/step
# Epoch 4305/10000
#
# Epoch 04305: val_loss improved from 436764.71875 to 436517.59375, saving model to ./model\4305-436517.5938.hdf5
# 35/35 - 0s - loss: 335972.0000 - val_loss: 436517.5938 - 50ms/epoch - 1ms/step
# Epoch 4306/10000
#
# Epoch 04306: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335841.5625 - val_loss: 436954.4688 - 46ms/epoch - 1ms/step
# Epoch 4307/10000
#
# Epoch 04307: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335841.5625 - val_loss: 437064.5938 - 39ms/epoch - 1ms/step
# Epoch 4308/10000
#
# Epoch 04308: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 336059.9062 - val_loss: 436681.5938 - 43ms/epoch - 1ms/step
# Epoch 4309/10000
#
# Epoch 04309: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335783.9062 - val_loss: 437166.6875 - 39ms/epoch - 1ms/step
# Epoch 4310/10000
#
# Epoch 04310: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335937.5000 - val_loss: 437566.5000 - 41ms/epoch - 1ms/step
# Epoch 4311/10000
#
# Epoch 04311: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335843.4688 - val_loss: 436964.0625 - 37ms/epoch - 1ms/step
# Epoch 4312/10000
#
# Epoch 04312: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 336008.2812 - val_loss: 436804.0938 - 47ms/epoch - 1ms/step
# Epoch 4313/10000
#
# Epoch 04313: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335956.8750 - val_loss: 436884.5000 - 50ms/epoch - 1ms/step
# Epoch 4314/10000
#
# Epoch 04314: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335904.5625 - val_loss: 436903.6562 - 42ms/epoch - 1ms/step
# Epoch 4315/10000
#
# Epoch 04315: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 336051.8750 - val_loss: 437368.0625 - 40ms/epoch - 1ms/step
# Epoch 4316/10000
#
# Epoch 04316: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335847.0312 - val_loss: 436877.0000 - 44ms/epoch - 1ms/step
# Epoch 4317/10000
#
# Epoch 04317: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335902.6250 - val_loss: 436708.1250 - 42ms/epoch - 1ms/step
# Epoch 4318/10000
#
# Epoch 04318: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335868.5312 - val_loss: 437209.9375 - 48ms/epoch - 1ms/step
# Epoch 4319/10000
#
# Epoch 04319: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335890.5625 - val_loss: 437116.0312 - 45ms/epoch - 1ms/step
# Epoch 4320/10000
#
# Epoch 04320: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 336098.8750 - val_loss: 436995.5312 - 40ms/epoch - 1ms/step
# Epoch 4321/10000
#
# Epoch 04321: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335842.1875 - val_loss: 437195.1875 - 41ms/epoch - 1ms/step
# Epoch 4322/10000
#
# Epoch 04322: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335944.8125 - val_loss: 436817.9375 - 42ms/epoch - 1ms/step
# Epoch 4323/10000
#
# Epoch 04323: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335795.7188 - val_loss: 437144.5938 - 43ms/epoch - 1ms/step
# Epoch 4324/10000
#
# Epoch 04324: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335914.3750 - val_loss: 437034.1250 - 37ms/epoch - 1ms/step
# Epoch 4325/10000
#
# Epoch 04325: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335840.5000 - val_loss: 436972.5625 - 42ms/epoch - 1ms/step
# Epoch 4326/10000
#
# Epoch 04326: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335948.9688 - val_loss: 436872.5938 - 43ms/epoch - 1ms/step
# Epoch 4327/10000
#
# Epoch 04327: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335846.9375 - val_loss: 437096.5312 - 40ms/epoch - 1ms/step
# Epoch 4328/10000
#
# Epoch 04328: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335835.8125 - val_loss: 436859.4688 - 40ms/epoch - 1ms/step
# Epoch 4329/10000
#
# Epoch 04329: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335858.7812 - val_loss: 436888.8750 - 44ms/epoch - 1ms/step
# Epoch 4330/10000
#
# Epoch 04330: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335815.6250 - val_loss: 437053.9688 - 44ms/epoch - 1ms/step
# Epoch 4331/10000
#
# Epoch 04331: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335880.3125 - val_loss: 437130.6875 - 41ms/epoch - 1ms/step
# Epoch 4332/10000
#
# Epoch 04332: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335978.2500 - val_loss: 437018.6562 - 45ms/epoch - 1ms/step
# Epoch 4333/10000
#
# Epoch 04333: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335871.6250 - val_loss: 436835.2812 - 38ms/epoch - 1ms/step
# Epoch 4334/10000
#
# Epoch 04334: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335866.9688 - val_loss: 436574.2188 - 43ms/epoch - 1ms/step
# Epoch 4335/10000
#
# Epoch 04335: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335854.0625 - val_loss: 436831.8125 - 43ms/epoch - 1ms/step
# Epoch 4336/10000
#
# Epoch 04336: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335936.0312 - val_loss: 436896.5000 - 46ms/epoch - 1ms/step
# Epoch 4337/10000
#
# Epoch 04337: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335856.7812 - val_loss: 436996.1250 - 36ms/epoch - 1ms/step
# Epoch 4338/10000
#
# Epoch 04338: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335861.6562 - val_loss: 436664.7188 - 41ms/epoch - 1ms/step
# Epoch 4339/10000
#
# Epoch 04339: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335822.5000 - val_loss: 436986.0312 - 48ms/epoch - 1ms/step
# Epoch 4340/10000
#
# Epoch 04340: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335841.6875 - val_loss: 436766.6562 - 43ms/epoch - 1ms/step
# Epoch 4341/10000
#
# Epoch 04341: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335869.4375 - val_loss: 436829.3438 - 44ms/epoch - 1ms/step
# Epoch 4342/10000
#
# Epoch 04342: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335932.0000 - val_loss: 436916.7500 - 43ms/epoch - 1ms/step
# Epoch 4343/10000
#
# Epoch 04343: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335956.0000 - val_loss: 437023.6562 - 41ms/epoch - 1ms/step
# Epoch 4344/10000
#
# Epoch 04344: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335870.1875 - val_loss: 436902.5938 - 43ms/epoch - 1ms/step
# Epoch 4345/10000
#
# Epoch 04345: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335817.4062 - val_loss: 436918.8125 - 39ms/epoch - 1ms/step
# Epoch 4346/10000
#
# Epoch 04346: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335839.3125 - val_loss: 436813.8750 - 44ms/epoch - 1ms/step
# Epoch 4347/10000
#
# Epoch 04347: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335803.5000 - val_loss: 436822.0312 - 42ms/epoch - 1ms/step
# Epoch 4348/10000
#
# Epoch 04348: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335837.0312 - val_loss: 436878.5625 - 47ms/epoch - 1ms/step
# Epoch 4349/10000
#
# Epoch 04349: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335912.4062 - val_loss: 436623.3750 - 38ms/epoch - 1ms/step
# Epoch 4350/10000
#
# Epoch 04350: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335721.5938 - val_loss: 437348.1250 - 45ms/epoch - 1ms/step
# Epoch 4351/10000
#
# Epoch 04351: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 336053.9062 - val_loss: 437034.6250 - 37ms/epoch - 1ms/step
# Epoch 4352/10000
#
# Epoch 04352: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335885.3750 - val_loss: 437219.1875 - 44ms/epoch - 1ms/step
# Epoch 4353/10000
#
# Epoch 04353: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335804.2812 - val_loss: 436931.1875 - 44ms/epoch - 1ms/step
# Epoch 4354/10000
#
# Epoch 04354: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335876.3125 - val_loss: 436896.3438 - 39ms/epoch - 1ms/step
# Epoch 4355/10000
#
# Epoch 04355: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335970.3438 - val_loss: 437463.8438 - 46ms/epoch - 1ms/step
# Epoch 4356/10000
#
# Epoch 04356: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335847.4688 - val_loss: 436884.0312 - 46ms/epoch - 1ms/step
# Epoch 4357/10000
#
# Epoch 04357: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335810.4688 - val_loss: 437194.8125 - 44ms/epoch - 1ms/step
# Epoch 4358/10000
#
# Epoch 04358: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335867.8438 - val_loss: 436847.8438 - 46ms/epoch - 1ms/step
# Epoch 4359/10000
#
# Epoch 04359: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335816.9688 - val_loss: 437178.8438 - 41ms/epoch - 1ms/step
# Epoch 4360/10000
#
# Epoch 04360: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335879.5625 - val_loss: 436767.5625 - 43ms/epoch - 1ms/step
# Epoch 4361/10000
#
# Epoch 04361: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335913.7500 - val_loss: 436680.9375 - 40ms/epoch - 1ms/step
# Epoch 4362/10000
#
# Epoch 04362: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335944.7188 - val_loss: 437229.6875 - 39ms/epoch - 1ms/step
# Epoch 4363/10000
#
# Epoch 04363: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335791.8125 - val_loss: 436981.5000 - 42ms/epoch - 1ms/step
# Epoch 4364/10000
#
# Epoch 04364: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335927.8438 - val_loss: 436696.2812 - 42ms/epoch - 1ms/step
# Epoch 4365/10000
#
# Epoch 04365: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335753.3125 - val_loss: 436964.1875 - 49ms/epoch - 1ms/step
# Epoch 4366/10000
#
# Epoch 04366: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335780.1250 - val_loss: 437006.2812 - 45ms/epoch - 1ms/step
# Epoch 4367/10000
#
# Epoch 04367: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335872.4375 - val_loss: 436794.1250 - 38ms/epoch - 1ms/step
# Epoch 4368/10000
#
# Epoch 04368: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335782.7188 - val_loss: 436989.6562 - 46ms/epoch - 1ms/step
# Epoch 4369/10000
#
# Epoch 04369: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335842.1250 - val_loss: 436996.0938 - 44ms/epoch - 1ms/step
# Epoch 4370/10000
#
# Epoch 04370: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335774.5000 - val_loss: 436979.3750 - 47ms/epoch - 1ms/step
# Epoch 4371/10000
#
# Epoch 04371: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335783.3125 - val_loss: 436927.6875 - 40ms/epoch - 1ms/step
# Epoch 4372/10000
#
# Epoch 04372: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335785.8750 - val_loss: 436692.3438 - 41ms/epoch - 1ms/step
# Epoch 4373/10000
#
# Epoch 04373: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335885.8750 - val_loss: 436852.1562 - 36ms/epoch - 1ms/step
# Epoch 4374/10000
#
# Epoch 04374: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335771.9688 - val_loss: 436681.8125 - 44ms/epoch - 1ms/step
# Epoch 4375/10000
#
# Epoch 04375: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335860.2188 - val_loss: 436853.8750 - 48ms/epoch - 1ms/step
# Epoch 4376/10000
#
# Epoch 04376: val_loss did not improve from 436517.59375
# 35/35 - 0s - loss: 335809.6562 - val_loss: 437115.6875 - 41ms/epoch - 1ms/step
# Epoch 4377/10000
#
# Epoch 04377: val_loss improved from 436517.59375 to 436432.81250, saving model to ./model\4377-436432.8125.hdf5
# 35/35 - 0s - loss: 335985.1250 - val_loss: 436432.8125 - 54ms/epoch - 2ms/step
# Epoch 4378/10000
#
# Epoch 04378: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335824.8125 - val_loss: 436949.0312 - 48ms/epoch - 1ms/step
# Epoch 4379/10000
#
# Epoch 04379: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335932.0000 - val_loss: 437080.8750 - 47ms/epoch - 1ms/step
# Epoch 4380/10000
#
# Epoch 04380: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335802.9375 - val_loss: 436948.9688 - 40ms/epoch - 1ms/step
# Epoch 4381/10000
#
# Epoch 04381: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335848.3750 - val_loss: 436801.5312 - 48ms/epoch - 1ms/step
# Epoch 4382/10000
#
# Epoch 04382: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335892.2188 - val_loss: 436932.4375 - 41ms/epoch - 1ms/step
# Epoch 4383/10000
#
# Epoch 04383: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335797.7500 - val_loss: 436832.7500 - 39ms/epoch - 1ms/step
# Epoch 4384/10000
#
# Epoch 04384: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335822.6250 - val_loss: 437079.1250 - 44ms/epoch - 1ms/step
# Epoch 4385/10000
#
# Epoch 04385: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335774.9375 - val_loss: 436808.9688 - 42ms/epoch - 1ms/step
# Epoch 4386/10000
#
# Epoch 04386: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335842.2500 - val_loss: 437199.2188 - 40ms/epoch - 1ms/step
# Epoch 4387/10000
#
# Epoch 04387: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335869.2188 - val_loss: 436547.0312 - 43ms/epoch - 1ms/step
# Epoch 4388/10000
#
# Epoch 04388: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335973.4375 - val_loss: 437269.4375 - 40ms/epoch - 1ms/step
# Epoch 4389/10000
#
# Epoch 04389: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 336005.4062 - val_loss: 436444.8125 - 40ms/epoch - 1ms/step
# Epoch 4390/10000
#
# Epoch 04390: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335849.7500 - val_loss: 437239.8125 - 41ms/epoch - 1ms/step
# Epoch 4391/10000
#
# Epoch 04391: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 336021.6562 - val_loss: 436689.4688 - 44ms/epoch - 1ms/step
# Epoch 4392/10000
#
# Epoch 04392: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335735.8125 - val_loss: 436962.5312 - 38ms/epoch - 1ms/step
# Epoch 4393/10000
#
# Epoch 04393: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335940.9688 - val_loss: 436834.9062 - 42ms/epoch - 1ms/step
# Epoch 4394/10000
#
# Epoch 04394: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335877.8750 - val_loss: 437024.5312 - 40ms/epoch - 1ms/step
# Epoch 4395/10000
#
# Epoch 04395: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335826.7812 - val_loss: 437029.5000 - 38ms/epoch - 1ms/step
# Epoch 4396/10000
#
# Epoch 04396: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335829.3438 - val_loss: 437228.1250 - 41ms/epoch - 1ms/step
# Epoch 4397/10000
#
# Epoch 04397: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335763.0312 - val_loss: 436687.3750 - 41ms/epoch - 1ms/step
# Epoch 4398/10000
#
# Epoch 04398: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 336021.9375 - val_loss: 437004.0625 - 41ms/epoch - 1ms/step
# Epoch 4399/10000
#
# Epoch 04399: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335898.7188 - val_loss: 436656.3438 - 44ms/epoch - 1ms/step
# Epoch 4400/10000
#
# Epoch 04400: val_loss did not improve from 436432.81250
# 35/35 - 0s - loss: 335784.3750 - val_loss: 436748.6250 - 42ms/epoch - 1ms/step

# %%
X_valid
# Out:
#       date_block_num  store_id
# 897               19        18
# 1507              32        14
# 511               11        15
# 1368              28        57
# 310                6        50
# ...              ...       ...
# 1308              27        39
# 1367              28        56
# 1558              33        22
# 1185              24        58
# 793               17        13
#
# [476 rows x 2 columns]

# %%
# 예측 값과 실제 값의 비교
Y_prediction = model_mlp.predict(X_valid).flatten()
for i in [1,2,310,264]:
    a = Y_valid[i] 
    prediction = Y_prediction[i]
    print("실제: {:.3f}, 예상: {:.3f}".format(a, prediction))

from sklearn.metrics import r2_score
r2_y_predict = r2_score(Y_valid, Y_prediction)
print('R2 : ', r2_y_predict)
# Out:
# 실제: 566.934, 예상: 1592.664
# 실제: 1013.132, 예상: 1217.677
# 실제: 812.969, 예상: 1246.282
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 264
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/1129441183.py in <module>
#       2 Y_prediction = model_mlp.predict(X_valid).flatten()
#       3 for i in [1,2,310,264]:
# ----> 4     a = Y_valid[i]
#       5     prediction = Y_prediction[i]
#       6     print("실제: {:.3f}, 예상: {:.3f}".format(a, prediction))
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     957
#     958         elif key_is_scalar:
# --> 959             return self._get_value(key)
#     960
#     961         if is_hashable(key):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1068
#    1069         # Similar to Index.get_value, but we do not fall back to positional
# -> 1070         loc = self.index.get_loc(label)
#    1071         return self.index._get_values_for_loc(self, loc, label)
#    1072
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 264

# %%
mlp_train_pred = model_mlp.predict(X_train.values)
mlp_valid_pred = model_mlp.predict(X_valid.values)

Y_train_ = pd.DataFrame({'y_true': Y_train, 'y_pred': mlp_train_pred.reshape(mlp_train_pred.shape[0],)}).set_index(X_train.index).sort_index()
Y_train_ = pd.merge(Y_train_, train_gp,
         left_index=True, right_index=True,
         how='left')

Y_valid_ = pd.DataFrame({'y_true': Y_valid, 'y_pred': mlp_valid_pred.reshape(mlp_valid_pred.shape[0],)}).set_index(X_valid.index).sort_index()
Y_valid_ = pd.merge(Y_valid_, train_gp,
         left_index=True, right_index=True,
         how='left')

# %%
from sklearn import metrics


def scoring(y_true, y_pred):
    r2 = round(metrics.r2_score(y_true, y_pred) * 100, 3)
    #     mae = round(metrics.mean_absolute_error(y_true, y_pred),3)
    corr = round(np.corrcoef(y_true, y_pred)[0, 1], 3)
    mape = round(
        metrics.mean_absolute_percentage_error(y_true, y_pred) * 100, 3)
    rmse = round(metrics.mean_squared_error(y_true, y_pred, squared=False), 3)

    df = pd.DataFrame({
        'R2': r2,
        "Corr": corr,
        "RMSE": rmse,
        "MAPE": mape
    },
                      index=[0])
    return df

# %%
scoring(Y_train_.y_true, Y_train_.y_pred)
# Out:
#        R2   Corr     RMSE    MAPE
# 0  14.294  0.378  579.389  29.766

# %%
def abline(slope, intercept):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '--')
    
def MinMax(y_true, y_pred, m="min") :
    if(m == "min") :
        return min(min(y_true),min(y_pred)) -2
    else :
        return max(max(y_true),max(y_pred)) +2
        
def myGraph(temp, title) :
    fig, axs = plt.subplots(1,2,figsize=(20,5), gridspec_kw={'width_ratios': [2.5, 1]})
    axs[0].plot(temp.date, temp.y_true, label = "Original")
    axs[0].plot(temp.date, temp.y_pred, label = " Predicted")
    axs[0].legend(loc='upper right')
    axs[0].title.set_text(title)
    axs[0].set_xlabel("Date")
    axs[0].set_ylabel("Sales")


    axs[1].plot(temp.y_true,temp.y_pred,'.')
    plt.xlim(MinMax(temp.y_true,temp.y_pred),MinMax(temp.y_true,temp.y_pred,"max"))
    plt.ylim(MinMax(temp.y_true,temp.y_pred),MinMax(temp.y_true,temp.y_pred,"max"))
    abline(1,0)
    plt.title(title)
    plt.xlabel("Original")
    plt.ylabel("Predicted")

# %%
Y_valid_
# Out:
#            y_true       y_pred  date_block_num  store_id    price_hap
# 1      566.933927   846.456665               0         1   566.933927
# 2     1013.132400   846.312683               0         2  1013.132400
# 4      756.951426   846.024780               0         4   756.951426
# 5      842.967117   845.736816               0         6   842.967117
# 9     1385.946801   844.873047               0        12  1385.946801
# ...           ...          ...             ...       ...          ...
# 1578  1641.084223  1425.338013              33        50  1641.084223
# 1579  1199.816794  1415.063721              33        52  1199.816794
# 1582  1133.959657  1394.515015              33        56  1133.959657
# 1583  1153.838663  1389.378052              33        57  1153.838663
# 1585  1334.316872  1379.103638              33        59  1334.316872
#
# [476 rows x 5 columns]

# %%
temp = Y_valid_.loc[(Y_valid_.store_id == 60) ,].sort_values('date_block_num')
print(temp)
# Out:
# Empty DataFrame
# Columns: [y_true, y_pred, date_block_num, store_id, price_hap]
# Index: []

# %%
scoring(temp.y_true, temp.y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/3676933333.py in <module>
# ----> 1 scoring(temp.y_true, temp.y_pred)
#
# ~\AppData\Local\Temp/ipykernel_4528/3525146474.py in scoring(y_true, y_pred)
#       3
#       4 def scoring(y_true, y_pred):
# ----> 5     r2 = round(metrics.r2_score(y_true, y_pred) * 100, 3)
#       6     #     mae = round(metrics.mean_absolute_error(y_true, y_pred),3)
#       7     corr = round(np.corrcoef(y_true, y_pred)[0, 1], 3)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     787     -3.0
#     788     """
# --> 789     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     790         y_true, y_pred, multioutput
#     791     )
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      93     """
#      94     check_consistent_length(y_true, y_pred)
# ---> 95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      97
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     803         n_samples = _num_samples(array)
#     804         if n_samples < ensure_min_samples:
# --> 805             raise ValueError(
#     806                 "Found array with %d sample(s) (shape=%s) while a"
#     807                 " minimum of %d is required%s."
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
myGraph(temp, 'Store_id = %d' % (60,22170))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/550573906.py in <module>
# ----> 1 myGraph(temp, 'Store_id = %d' % (60,22170))
#
# TypeError: not all arguments converted during string formatting

# %%
sales_train_c = sales_train.copy()

# %%
sales_train_c.drop(['date','item_price', 'item_cnt_day','price_hap'],axis =1, inplace=True)

# %%
sales_train_c
# Out:
#          date_block_num  shop_id  item_id
# 0                     0       59    22154
# 1                     0       25     2552
# 2                     0       25     2552
# 3                     0       25     2554
# 4                     0       25     2555
# ...                 ...      ...      ...
# 2935844              33       25     7409
# 2935845              33       25     7460
# 2935846              33       25     7459
# 2935847              33       25     7440
# 2935848              33       25     7460
#
# [2935849 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

y = sales_train['price_hap']
X = sales_train_c.copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

print(X_train.shape, X_test.shape ,y_train.shape, y_test.shape)
print(X , y)
# Out:
# (2055094, 3) (880755, 3) (2055094,) (880755,)
#          date_block_num  shop_id  item_id
# 0                     0       59    22154
# 1                     0       25     2552
# 2                     0       25     2552
# 3                     0       25     2554
# 4                     0       25     2555
# ...                 ...      ...      ...
# 2935844              33       25     7409
# 2935845              33       25     7460
# 2935846              33       25     7459
# 2935847              33       25     7440
# 2935848              33       25     7460
#
# [2935849 rows x 3 columns] 0           999.00
# 1           899.00
# 2          -899.00
# 3          1709.05
# 4          1099.00
#             ...
# 2935844     299.00
# 2935845     299.00
# 2935846     349.00
# 2935847     299.00
# 2935848     299.00
# Name: price_hap, Length: 2935849, dtype: float64

# %%
#month_sales_data=sales_train.groupby(["date_block_num","shop_id","item_id"]).agg({"date":["min",'max'],"item_price":"mean","item_cnt_day":"sum", "price_hap":"sum"})

# %%
#month_sales_data

# %%
#month_sales_data_c = month_sales_data.copy()
#month_sales_data_c.drop(['item_price', 'item_cnt_day','price_hap'],axis =1, inplace=True)

# %%
#month_sales_data_c.drop(['date'],axis =1, inplace=True)

# %%
#from sklearn.model_selection import train_test_split

#y = month_sales_data['price_hap']
#X = month_sales_data_c.copy()

#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

#print(y)
#print(y_test)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

model = Sequential()
model.add(Dense(9, input_dim=3, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',
              optimizer='adam')

# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='loss', patience=40)

model.fit(X_train, y_train, epochs=10000, batch_size=10)

# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    print("실제: {:.3f}, 예상: {:.3f}".format(label, prediction))

from sklearn.metrics import r2_score
r2_y_predict = r2_score(y_test, Y_prediction)
print('R2 : ', r2_y_predict)
# Out:
# Epoch 1/10000
# 205510/205510 [==============================] - 119s 579us/step - loss: 33541458.0000
# Epoch 2/10000
#   1768/205510 [..............................] - ETA: 2:07 - loss: 13807207.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9252/64418495.py in <module>
#      22 early_stopping_callback = EarlyStopping(monitor='loss', patience=40)
#      23
# ---> 24 model.fit(X_train, y_train, epochs=10000, batch_size=10)
#      25
#      26 # 예측 값과 실제 값의 비교
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1206         callbacks.on_epoch_begin(epoch)
#    1207         with data_handler.catch_stop_iteration():
# -> 1208           for step in data_handler.steps():
#    1209             with tf.profiler.experimental.Trace(
#    1210                 'train',
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py in steps(self)
#    1248       if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1249         break
# -> 1250       original_spe = self._steps_per_execution.numpy().item()
#    1251       can_run_full_execution = (
#    1252           original_spe == 1 or
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in numpy(self)
#     643   def numpy(self):
#     644     if context.executing_eagerly():
# --> 645       return self.read_value().numpy()
#     646     raise NotImplementedError(
#     647         "numpy() is only available when eager execution is enabled.")
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in read_value(self)
#     721     # Return an identity so it can get placed on whatever device the context
#     722     # specifies instead of the device where the variable is.
# --> 723     return array_ops.identity(value)
#     724
#     725   def sparse_read(self, indices, name=None):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\array_ops.py in identity(input, name)
#     288     # variables. Variables have correct handle data when graph building.
#     289     input = ops.convert_to_tensor(input)
# --> 290   ret = gen_array_ops.identity(input, name=name)
#     291   # Propagate handle data for happier shape inference for resource variables.
#     292   if hasattr(input, "_handle_data"):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in identity(input, name)
#    4061   if tld.is_eager:
#    4062     try:
# -> 4063       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    4064         _ctx, "Identity", name, input)
#    4065       return _result
#
# KeyboardInterrupt:

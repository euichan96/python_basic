# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers, initializers, regularizers, metrics

np.random.seed(3)
tf.random.set_seed(3)

train_datagen = ImageDataGenerator(rescale=1./255,
                                  horizontal_flip=True,     #수평 대칭 이미지를 50% 확률로 만들어 추가합니다.
                                  width_shift_range=0.1,  #전체 크기의 10% 범위에서 좌우로 이동합니다.
                                  height_shift_range=0.1, #마찬가지로 위, 아래로 이동합니다.
                                  #rotation_range=5,
                                  #shear_range=0.7,
                                  #zoom_range=[0.9, 2.2],
                                  #vertical_flip=True,
                                  fill_mode='nearest') 

train_generator = train_datagen.flow_from_directory(
       './train',   #학습셋이 있는 폴더의 위치입니다.
       target_size=(150, 150),
       batch_size=5,
       class_mode='binary')

#테스트 셋은 이미지 부풀리기 과정을 진행하지 않습니다.
test_datagen = ImageDataGenerator(rescale=1./255)  

test_generator = test_datagen.flow_from_directory(
       './test',   #테스트셋이 있는 폴더의 위치입니다.
       target_size=(150, 150),
       batch_size=5,
       class_mode='binary')


# 앞서 배운 CNN 모델을 만들어 적용해 보겠습니다.
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150,150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))

#모델을 컴파일 합니다. 
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0002), metrics=['accuracy'])

#모델을 실행합니다
history = model.fit_generator(
       train_generator,
       steps_per_epoch=30,
       epochs=20,
       validation_data=test_generator,
       validation_steps=10)

#결과를 그래프로 표현하는 부분입니다.
acc= history.history['accuracy']
val_acc= history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))  
plt.plot(x_len, acc, marker='.', c="red", label='Trainset_acc')
plt.plot(x_len, val_acc, marker='.', c="lightcoral", label='Testset_acc')
plt.plot(x_len, y_vloss, marker='.', c="cornflowerblue", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

plt.legend(loc='upper right') 
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# C:\Users\82109\AppData\Local\Temp/ipykernel_15832/856109435.py:64: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/20
# 30/30 [==============================] - 2s 54ms/step - loss: 0.7040 - accuracy: 0.4400 - val_loss: 0.6893 - val_accuracy: 0.4800
# Epoch 2/20
# 30/30 [==============================] - 1s 48ms/step - loss: 0.6957 - accuracy: 0.4800 - val_loss: 0.6672 - val_accuracy: 0.6400
# Epoch 3/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.6802 - accuracy: 0.5600 - val_loss: 0.6648 - val_accuracy: 0.5600
# Epoch 4/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.6688 - accuracy: 0.6133 - val_loss: 0.6612 - val_accuracy: 0.8000
# Epoch 5/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.6765 - accuracy: 0.5800 - val_loss: 0.6515 - val_accuracy: 0.7400
# Epoch 6/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.6519 - accuracy: 0.6000 - val_loss: 0.6105 - val_accuracy: 0.7800
# Epoch 7/20
# 30/30 [==============================] - 1s 47ms/step - loss: 0.6260 - accuracy: 0.6600 - val_loss: 0.5554 - val_accuracy: 0.8600
# Epoch 8/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.6006 - accuracy: 0.7533 - val_loss: 0.6001 - val_accuracy: 0.5800
# Epoch 9/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.5777 - accuracy: 0.7200 - val_loss: 0.5322 - val_accuracy: 0.7600
# Epoch 10/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.5132 - accuracy: 0.7533 - val_loss: 0.4817 - val_accuracy: 0.7600
# Epoch 11/20
# 30/30 [==============================] - 1s 47ms/step - loss: 0.4339 - accuracy: 0.8400 - val_loss: 0.3208 - val_accuracy: 0.9400
# Epoch 12/20
# 30/30 [==============================] - 1s 47ms/step - loss: 0.4868 - accuracy: 0.8000 - val_loss: 0.4675 - val_accuracy: 0.9000
# Epoch 13/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.4608 - accuracy: 0.8000 - val_loss: 0.4506 - val_accuracy: 0.7800
# Epoch 14/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.4518 - accuracy: 0.7800 - val_loss: 0.2807 - val_accuracy: 0.9400
# Epoch 15/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.3451 - accuracy: 0.8867 - val_loss: 0.2087 - val_accuracy: 0.9400
# Epoch 16/20
# 30/30 [==============================] - 2s 51ms/step - loss: 0.3618 - accuracy: 0.8467 - val_loss: 0.2161 - val_accuracy: 0.9600
# Epoch 17/20
# 30/30 [==============================] - 1s 47ms/step - loss: 0.3024 - accuracy: 0.8800 - val_loss: 0.3164 - val_accuracy: 0.8600
# Epoch 18/20
# 30/30 [==============================] - 1s 47ms/step - loss: 0.3054 - accuracy: 0.9000 - val_loss: 0.1887 - val_accuracy: 0.9600
# Epoch 19/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2363 - accuracy: 0.9133 - val_loss: 0.1215 - val_accuracy: 0.9800
# Epoch 20/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2017 - accuracy: 0.9333 - val_loss: 0.1054 - val_accuracy: 1.0000

# %%
#결과를 그래프로 표현하는 부분입니다.
acc= history.history['accuracy']
val_acc= history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))  
plt.plot(x_len, acc, marker='.', c="red", label='Trainset_acc')
plt.plot(x_len, val_acc, marker='.', c="lightcoral", label='Testset_acc')
plt.plot(x_len, y_vloss, marker='.', c="cornflowerblue", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

plt.legend(loc='upper right') 
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()

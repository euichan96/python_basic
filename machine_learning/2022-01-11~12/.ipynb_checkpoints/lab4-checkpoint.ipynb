# %%
import requests
from bs4 import BeautifulSoup
title = []
info_new = []
urlstr = 'http://media.daum.net/ranking/popular/'
r = requests.get(urlstr)

bs = BeautifulSoup(r.text, 'html.parser')
news = bs.select('ul.list_news2 > li > div > strong > a.link_txt')
info = bs.select('span.info_news')

for news_name in news:
    title.append(news_name.string)
    
for info_name in info:
    info_new.append(info_name.string)

print("-- 뉴스 제목 --")
print(title)
print("-- 뉴스 출판사? 방송사? --")
print(info_new)
with open('news.csv', "wt", encoding="utf-8") as f:
    f.write('newstitle, newscomname \n')  
    for i in range(50):
        f.write(title[i]+","+info_new[i]+'\n')  
print(len(title), len(info_new))
# Out:
# -- 뉴스 제목 --
# ["'이재명 변호사비 대납의혹' 녹취록 제보자 숨진 채 발견", '오스템임플란트 횡령 직원 부친 시신부검..유서에 "잘 있어라"', '[시선집중] 전원책 "尹 지지율 급반등 \'여가부 폐지\' 덕분.. 이제 조금 \'정치인\' 된 듯"', '이준석·홍준표, \'이재명 제보자 사망\'.."왜 자꾸 죽어 나가나"', '숨진채 발견된 \'李 의혹\' 제보자, 한달전 "난 절대 자살 안한다"', '[출발]KBS 이어 MBN TV토론 실무협의도 무산? 박주민 "대체 무슨 내막인지"', '강남 클럽서 \'귀 절단\' 엽기 사건..女 "술 깨보니 잘려 있었다"(종합)', '안철수 측, 이준석에 "적당히 하라"..\'尹과 단일화\' 여지', '광주시, 현대산업개발 모든 건축현장 공사중지 명령(종합)', '박영선 "김건희? 어느 후보 부인이 기자와 7시간 통화할까"', '"남녀 살해 후 술마시다 잠들어" 50대 중국동포 무기징역 확정', '文정부서 숱한 고위직 제안..끝내 거절 "親文훌리건 아닌 상냥·명랑 좌파 하고파"', '춘천 신축공사 초고층 아파트 49층서 불..인부 1명 연기흡입(종합)', '\'집단 성폭행\' 최종훈, 출소 후 신앙생활 근황..母 "억울"', '광주 붕괴 실종자 6명 휴대폰 GPS..전날 같은 위치, 움직임 없어', '한국인이 불신하는 나라 중국·일본..가장 신뢰하는 나라는?', "[단독] '7시간 김건희 통화' 녹음 파일 공개된다", '"무서워서 어떻게 사나, 부수고 다시 지어라"', "'소상공인 100만원, 프리랜서 50만원'..서울시, 코로나 재난지원에 8576억원 편성", '"220억 공장을 5억에 매각"..회삿돈 빼돌리고, 자녀에게 회사 불법승계한 유명가전제품 회장·대표 적발', "'허리 꼿꼿한' 노인 되려면 꼭 키워야 하는 근육 3", '유튜브에서 1967만회 대박난 창원 수소청소트럭.."감동" 댓글 이어져[영상]', '숨진 \'이재명 변호사비 대납의혹\' 제보자..한달전 "절대 자살 안해"', '"영끌로 겨우 집 한 채 마련했는데.." 강북 집주인들 속탄다', '깨시연 이민구 "\'이재명 변호사비 대납 의혹\' 최초 제보자, 극단 선택할 인물 아냐..황망"', '"오스템임플란트 범인, 왜 밀항하지 않았나?"', '"백발 노모 위해 개발했다" 100만병 팔린 K뷰티 샴푸 "살려달라"', '이재명 36.9%, 윤석열 39.2%..단일화 적합도 안철수 39.6% 윤석열 35.6% [리얼미터]', '\'이재명 변호사비 대납 의혹\' 제보자 사망..이준석 "지켜보고 분노하자"', '정의, 李 변호사비 대납의혹 제보자 사망에 "오싹하고 섬뜩"', '\'이재명 변호사비 대납 의혹\' 제보자 사망..경찰 "타살 정황 없어"', '中매체 "김치, 한국에만 중요"..서경덕 "근데 왜 훔치나"', '\'이재명 변호사비 대납 의혹\' 제보자 사망.. 홍준표 "조폭 연계 연쇄 죽음 아닌가"', '반찬 던지고 "백신 왜 안 맞아?"..미접종자 거지 취급한 칼국숫집', '"죽는 줄 알았다..삼풍백화점 생각 나더라" 광주 붕괴 목격자 증언', '"택배 훔쳐 간다" 신고..잡고 보니 택배 대리점 사장, 딱한 사정', '잘못 온 문자에 \'외도 확신\'..아내 살해한 남편 "어리석었다"', '최영·이성계와 어깨를 나란히 한 명장을 기리는 곳', '"사윗감으로 이재명·윤석열 누가 나을까요?"', '이재명 측, \'제보자 사망\'에 "아무 관계 없다..국힘 억지주장"', '신규확진, 엿새만에 4000명대.."거리두기, 자영업자 고려할 것"', '현대산업개발 "참담하고 부끄러운 사고..역량 다 해 수습하겠다"', '도대체 39층 아파트 어떻게 지었길래..', '"이젠 아무데나 안 꽂는다"..통장 아끼기 시작한 청약자들', '[영상] 울산 SK에너지 공장 ESS 화재 현장', '"강남 클럽서 보낸 약 2시간..누군가 내 귀를 \'싹둑\' 절단했다"', "레이저빔으로 대공미사일 무력화..'DIRCM' 비행시험 성공", "'신의 직장' 한국은행 구내식당 수준이..김밥 한줄에 컵라면 하나", '[무등의 아침] "\'외벽 붕괴\' 광주 아파트 건물, 철거 후 재시공 바람직"', "'이재명 변호사비 의혹' 녹취록 폭로자 숨진 채 발견"]
# -- 뉴스 출판사? 방송사? --
# ['연합뉴스', '연합뉴스', 'MBC', '뉴시스', '중앙일보', 'YTN', '뉴스1', '헤럴드경제', '뉴스1', '노컷뉴스', '서울신문', '문화일보', '연합뉴스', '뉴스1', '뉴스1', '중앙일보', '오마이뉴스', '중앙일보', '경향신문', '경향신문', '헬스조선', '중앙일보', '머니투데이', '한국경제', '데일리안', '노컷뉴스', '머니투데이', '경향신문', '뉴스1', '연합뉴스', '머니투데이', '국민일보', '세계일보', '이데일리', '서울경제', '머니투데이', '이데일리', '오마이뉴스', '신동아', '이데일리', '뉴시스', '경향신문', '중앙일보', '한국경제', '서울신문', '이데일리', '연합뉴스', '머니투데이', 'KBS', 'YTN']
# 50 50

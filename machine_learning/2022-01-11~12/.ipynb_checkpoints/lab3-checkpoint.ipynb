# %%
import requests
from bs4 import BeautifulSoup
title = []
info_new = []
urlstr = 'http://media.daum.net/ranking/popular/'
r = requests.get(urlstr)

bs = BeautifulSoup(r.text, 'html.parser')
news = bs.select('div > strong > a.link_txt')
info = bs.select('span.info_news')

for news_name in news:
    title.append(news_name.string)
    
for info_name in info:
    info_new.append(info_name.string)

print("-- 뉴스 제목 --")
print(title)
print("-- 뉴스 출판사? 방송사? --")
print(info_new)
with open('news.csv', "wt", encoding="utf-8") as f:
    f.write('newstitle, newscomname \n')  
    for i in range(50):
        f.write(title[i]+","+info_new[i]+'\n')
# Out:
# -- 뉴스 제목 --
# ["'이재명 변호사비 대납의혹' 녹취록 제보자 숨진 채 발견", '박영선 "김건희? 어느 후보 부인이 기자와 7시간 통화할까"', '한국인이 불신하는 나라 중국·일본..가장 신뢰하는 나라는?', "[단독] '7시간 김건희 통화' 녹음 파일 공개된다", '광주시, 현대산업개발 모든 건축현장 공사중지 명령(종합)', '이준석·홍준표, \'이재명 제보자 사망\'.."왜 자꾸 죽어 나가나"', '[출발]KBS 이어 MBN TV토론 실무협의도 무산? 박주민 "대체 무슨 내막인지"', '\'이재명 변호사비 대납 의혹\' 제보자 사망..이준석 "지켜보고 분노하자"', '윤석열 "온라인 부동산 등기부등본 발급, 전면 무료화"', '"붕괴 순간, 제트기가 밀어 닥치는 줄..죽는다 생각했다" [영상]', '[시선집중] 전원책 "尹 지지율 급반등 \'여가부 폐지\' 덕분.. 이제 조금 \'정치인\' 된 듯"', '허벅지 만지며 "소주 한 잔 따라봐"..여성 업주 향하는 \'검은 손길\'', '"오스템임플란트 범인, 왜 밀항하지 않았나?"', "'이재명 변호사비 의혹' 녹취록 폭로자 숨진 채 발견", '대림동 번화가서 남녀 살해한 50대 중국동포, 무기징역 확정', '반찬 던지고 "백신 왜 안 맞아?"..미접종자 거지 취급한 칼국숫집', '신규확진, 엿새만에 4000명대.."거리두기, 자영업자 고려할 것"', '"남녀 살해 후 술마시다 잠들어" 50대 중국동포 무기징역 확정', '숨진 \'이재명 변호사비 대납의혹\' 제보자..한달전 "절대 자살 안해"', "'허리 꼿꼿한' 노인 되려면 꼭 키워야 하는 근육 3", '도대체 39층 아파트 어떻게 지었길래..', '강남 클럽서 \'귀 절단\' 엽기 사건..女 "술 깨보니 잘려 있었다"(종합)', '"이젠 아무데나 안 꽂는다"..통장 아끼기 시작한 청약자들', "'신의 직장' 한국은행 구내식당 수준이..김밥 한줄에 컵라면 하나", "'멸공' 진화나선 정용진..신세계 불매에 '일베' 기름 부은 가세연", '안철수 측, 이준석에 "적당히 하라"..\'尹과 단일화\' 여지', '광주 붕괴 실종자 6명 휴대폰 GPS..전날 같은 위치, 움직임 없어', "安 '몸값' 고공행진하는데.. 야권 단일화 찬물 끼얹는 이준석", '38층부터 23층까지 무너진 \'광주 아파트\'.. "안전진단 후 수색"', "'소상공인 100만원, 프리랜서 50만원'..서울시, 코로나 재난지원에 8576억원 편성", '中매체 "김치, 한국에만 중요"..서경덕 "근데 왜 훔치나"', '[출발]이준석 "유시민, 꼰대의 전형"', "[단독]與 민감해하는 尹 '선제타격론', 알고보니 '민간인 열람가능'", '"코로나 백신 3번 맞으면 충분"-이스라엘 전문가', '300년 힘 모은 후지산, 폭발 땐 한반도도 위험하다', '190국 갈수 있는 한국 여권, 2022년 1계단 올라 2위로.. 1위는?', '윤석열 "北 선제타격" 발언에.."국민 불안" "전쟁광" 與 맹공', '"강남 클럽서 보낸 약 2시간..누군가 내 귀를 \'싹둑\' 절단했다"', '[최강시사] 진선미 전 여성가족부 장관 "여가부 폐지 논란에 늘 자책하고 있어..선거 표심 떠나 여가부 변화에 대한 계기 되길"', '최영·이성계와 어깨를 나란히 한 명장을 기리는 곳', '김건희-기자 7시간 통화 보도, 박영선 "세상 어느 후보 부인이.."', '[현장연결] 현대산업개발 "이번 사고에 머리 숙여 깊이 사죄"', '"사윗감으로 이재명·윤석열 누가 나을까요?"', '[최강시사] 김동연 "나는 국무총리 제의도 거절한 사람..단일화나 정치공학적 연대·이합집산 전혀 고려 않고 있어"', '깨시연 이민구 "\'이재명 변호사비 대납 의혹\' 최초 제보자, 극단 선택할 인물 아냐..황망"', '윤석열 지지율, 오차범위 내 선두.. 여가부 폐지 동의 50% 넘어[리얼미터]', '실종 6명 중 5명 한 곳서 신호.. 가족들 "내가 들어가 찾고 싶다"', "정용진의 '멸공'놀이..내부선 '공멸' 위기감", '[이슈 In] 일본, 선진국서 탈락하나..1인당 GDP OECD 평균 아래로', '"영끌로 겨우 집 한 채 마련했는데.." 강북 집주인들 속탄다', ' 브라질 남동부 폭우로 하루새 10명 사망', ' 2년 만에 등교 재개한 우간다..세계 최장 기간 학교 봉쇄']
# -- 뉴스 출판사? 방송사? --
# ['연합뉴스', '노컷뉴스', '중앙일보', '오마이뉴스', '뉴스1', '뉴시스', 'YTN', '뉴스1', '뉴시스', '서울경제', 'MBC', '머니투데이', '노컷뉴스', 'YTN', '동아일보', '이데일리', '뉴시스', '서울신문', '머니투데이', '헬스조선', '중앙일보', '뉴스1', '한국경제', '머니투데이', '이데일리', '헤럴드경제', '뉴스1', '쿠키뉴스', '이데일리', '경향신문', '국민일보', 'YTN', '머니투데이', '뉴스1', '머니투데이', '조선일보', '쿠키뉴스', '이데일리', 'KBS', '오마이뉴스', '이데일리', '연합뉴스TV', '신동아', 'KBS', '데일리안', '세계일보', '서울신문', '스포츠경향', '연합뉴스', '한국경제']

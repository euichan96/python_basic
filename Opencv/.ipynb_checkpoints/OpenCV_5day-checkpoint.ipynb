# %%
import numpy as np
import cv2
import sys

# %%
img = cv2.imread('./fig/cat.bmp')

if img is None:
    sys.exit('img read failed')
    
cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
cv2.imshow('image',img)

cv2.imwrite('test.png', img)
while True:
    key = cv2.waitKey()
    if key == 27 or key == ord('q'):
        break
        
cv2.destroyAllWindows()

# %%
img = cv2.imread('./fig/cat.bmp')
img_copy = img.copy()

cv2.imshow('image',img)

while True:
    key = cv2.waitKey()
    if key == 27 or key == ord('q'):
        break
        
    elif key == ord('e'):
        img = cv2.Canny(img, 50, 150)
        cv2.imshow('image',img)
        
    elif key == ord('i'):
        img = 255 - img
        cv2.imshow('image',img)
    
    elif key == ord('r'):
        img = img_copy
        cv2.imshow('image',img)
        
    elif key == ord('s'):
        cv2.imwrite('keyinput.png',img)
        
cv2.destroyAllWindows()

# %%
# mouse callback

# onMouse(event, x, y, flags, param) -> None
# event: 마우스 이벤트 종류 e.g., cv2.EVENT_LBUTTONDOWN
# x, y : 창을 기준으로 이벤트 발생좌표
# flags: 이벤트시 발생 상태 e.g., "ctrl"
# param: cv2.setMouseCallback()함수에서 설정한 데이터

def call_mouse(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(f'클릭 누름 : x={x}, y= {y}')
        
    elif event == cv2.EVENT_LBUTTONUP:
        print(f'클릭 땜 : x={x}, y= {y}')
        
    elif event == cv2.EVENT_MOUSEMOVE:
        if flags & cv2.EVENT_FLAG_LBUTTON:
            print(f'마우스 무빙 : x={x}, y= {y}')    
        

img = np.ones((480,600,3),np.uint8)*255

cv2.namedWindow('image')
# cv2.setMouseCallback(windowName, onMouse, param = None) -> None
    # windowName: 마우스이벤트를 수행할 창 이름
    # onMouse: 마우스 이벤트 콜벡함수
    # param: 콜백함수에 전달할 데이터
    
cv2.setMouseCallback('image', call_mouse)


cv2.imshow('image', img)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 클릭 누름 : x=256, y= 129
# 마우스 무빙 : x=258, y= 131
# 마우스 무빙 : x=259, y= 134
# 마우스 무빙 : x=262, y= 138
# 마우스 무빙 : x=264, y= 140
# 마우스 무빙 : x=268, y= 149
# 마우스 무빙 : x=272, y= 155
# 마우스 무빙 : x=275, y= 159
# 마우스 무빙 : x=279, y= 167
# 마우스 무빙 : x=283, y= 173
# 마우스 무빙 : x=289, y= 181
# 마우스 무빙 : x=292, y= 187
# 마우스 무빙 : x=294, y= 191
# 마우스 무빙 : x=297, y= 196
# 마우스 무빙 : x=300, y= 201
# 마우스 무빙 : x=304, y= 208
# 마우스 무빙 : x=307, y= 214
# 마우스 무빙 : x=311, y= 220
# 마우스 무빙 : x=314, y= 225
# 마우스 무빙 : x=317, y= 230
# 마우스 무빙 : x=318, y= 232
# 마우스 무빙 : x=321, y= 236
# 마우스 무빙 : x=324, y= 242
# 마우스 무빙 : x=325, y= 244
# 마우스 무빙 : x=327, y= 247
# 마우스 무빙 : x=330, y= 251
# 마우스 무빙 : x=330, y= 252
# 마우스 무빙 : x=331, y= 254
# 마우스 무빙 : x=332, y= 255
# 마우스 무빙 : x=333, y= 256
# 클릭 땜 : x=333, y= 256

# %%
import numpy as np
import cv2
import sys

oldx = oldy = -1

def onMouse(event, x, y, flags, param):
    global oldx, oldy
    
    if event == cv2.EVENT_LBUTTONDOWN:
        oldx, oldy = x, y 
        print(f'클릭 누름 : x={x}, y= {y}')
        
    elif event == cv2.EVENT_LBUTTONUP:
        print('EVENT_LBUTTONUP: %d, %d' % (x, y))
        
    elif event == cv2.EVENT_MOUSEMOVE:
        if flags & cv2.EVENT_FLAG_LBUTTON:
            cv2.line(img, (oldx, oldy), (x, y), (0, 0, 0), 4, cv2.LINE_AA)
            cv2.imshow('image', img)
            oldx, oldy = x, y       
       
    
img = np.ones((480,600,3),np.uint8)*255

cv2.namedWindow('image')
cv2.setMouseCallback('image', call_mouse)
cv2.imshow('image', img)

while True:
    key = cv2.waitKey()
    if key == 27 or key == ord('q'):
        break  
    elif key == ord('s'):
        cv2.imwrite('keyinput.png',img)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10456/3134359623.py in <module>
#      21
#      22 cv2.namedWindow('image')
# ---> 23 cv2.setMouseCallback('image', call_mouse)
#      24 cv2.imshow('image', img)
#      25
#
# NameError: name 'call_mouse' is not defined

# %%
import numpy as np
import cv2
import sys

def call_track(pos):
    global mask

    mask_ = mask * pos
    cv2.imshow('mask', mask_)

sunglass = cv2.imread('./fig/imgbin_sunglasses_1.png', cv2.IMREAD_UNCHANGED)#알파채널을 뽑을 수 있다.
mask = sunglass[:,:,-1] #알파채널 분리

mask[mask > 0] = 255

cv2.namedWindow('mask')
cv2.createTrackbar('level', 'mask', 10, 255, call_track)

cv2.imshow('mask', mask)
cv2.waitKey()
cv2.destroyAllWindows()
